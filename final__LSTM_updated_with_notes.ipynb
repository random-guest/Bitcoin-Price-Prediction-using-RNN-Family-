# %% [markdown]
# **This model will utilize the LSTM netwrok only to predicts next day closing price of the bitcoin.**

# %% [markdown]
# The next piece of code will **import the neccassary libraries** that will be used throughout the code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
sns.set_style("white")
import scipy 
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from IPython.core.pylabtools import figsize
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from keras.layers import *
from keras.models import *
from keras import backend as K

# Set random seed for reproducibility
tf.random.set_seed(42)

# %% [markdown]
# Now that we have the imported the required libraries, we need to get the data.
# We will do so by first **installing the historic crypto data api**, that will allow us to get the data of any crypto (mainly the famous ones), on any range we wish, for example, we can get the bitcoin data from a chosen date to a chosen date, per 60 seconds up to per 24 hrs.

# %%
# !pip install Historic-Crypto
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Historic-Crypto in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (1.21.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (1.24.3)

# %%
import warnings
warnings.filterwarnings("ignore")

# From the histroic cyrpto import the historical data
from Historic_Crypto import HistoricalData

# %% [markdown]
# Next step would be to **get the data** . The chosen data will be reterived chunk wise. Here, we will specify the name of the cryptocurrency we are interested in, for instance in our case 'BTC-USD' is the bitcoin one, then we should specify number of seconds that will seperate the data. For example, 86400 is the number of seconds in 1 day. So, we will reterive the data on a daily bases. Next, we will specify the starting date in the form of year-month-day-hour-minute and finally the ending date, in the same format.
#
# **In our case, we will reterive data between 01/01/2021 and 31/05/2022 on daily bases.**

# %%
btc_historicals = HistoricalData('BTC-USD',86400,'2021-01-01-00-00', '2022-07-01-00-00').retrieve_data() # cyrpto name, number of seconds, start date, end date
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-01-01T00:00:00
# Provisional End: 2021-10-28T00:00:00
# Data for chunk 1 of 2 extracted
# Provisional Start: 2021-10-28T00:00:00
# Provisional End: 2022-08-24T00:00:00
# Data for chunk 2 of 2 extracted

# %% [markdown]
# In the next few lines, we will try to have **a closer look at the data** and check whether it needs any cleaning or not.

# %%
# check the shape of the data
btc_historicals.shape
# Out:
# (546, 5)

# %%
# few the last 5 rows of the data
btc_historicals.tail()
# Out:
#                  low      high      open     close        volume
# time
# 2022-06-27  20500.00  21520.00  21024.85  20725.17  17440.942683
# 2022-06-28  20164.70  21189.99  20722.95  20252.89  17658.660417
# 2022-06-29  19823.43  20410.91  20253.50  20094.79  18278.451859
# 2022-06-30  18603.00  20143.53  20098.00  19985.62  28361.458762
# 2022-07-01  18938.33  20879.99  19985.62  19252.76  32977.000523

# %% [markdown]
# As we can observe, the data is in the form of low high open close volume, that means, on te given date, the lowest price was low, the higest price was high, the openning price was open, the closing price was close, and the volume of data that was exchanges was volume.

# %%
# Check out variables
btc_historicals.dtypes
# Out:
# low       float64
# high      float64
# open      float64
# close     float64
# volume    float64
# dtype: object

# %%
# assign a dummy variable to hold the data, so that incase we need to do any
# modifications, we wouldn't lose the orginal data.
tst = btc_historicals

# %%
# The data is clean already, but let us try to check for any null or NA vales.
print('Null Values:',tst.isnull().values.sum())
print('If any NA values:', tst.isnull().values.any())
# Out:
# Null Values: 0
# If any NA values: False

# %% [markdown]
# Next, we will need to do some modifications to the data we have. The first one will be to create a new variable called, Tomorrrow_Close which shifts the close price by 1 row and thus the last row will be deleted. This is done to add a new important feature so that our model will learn from.

# %%
# Create variable '‘TOMORROW_CLOSE’' which shifts 'Close' up by 1
tst['TOMORROW_CLOSE'] = tst['close'].shift(-1,fill_value=0)

# %%
# drop last row because we shifted value (remember this when you add your forecasting data)
tst.drop(tst.tail(1).index,inplace=True)

# %%
# Drop close column, since we created new ‘TOMORROW_CLOSE’
tst = tst.drop(columns=['close'])

# %%
tst.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
# check the shape of data to know how many sample we have
tst.shape
# Out:
# (545, 5)

# %%
# Split the data intro train data (90%) and test data (10%)

train_size = int(len(tst)*0.90)
train_dataset, test_dataset = tst.iloc[:train_size],tst.iloc[train_size:]

# %%
# Double check the split
train_dataset.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
# Double check the split
test_dataset.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2022-05-07  34785.00  36125.00  35999.10  11372.453192        34027.91
# 2022-05-08  33701.00  35499.93  35458.00  22357.511521        30078.27
# 2022-05-09  30010.00  34231.54  34033.49  55136.453328        31002.39
# 2022-05-10  29735.05  32645.49  30078.27  55818.019003        28972.34
# 2022-05-11  27682.38  32185.90  31002.39  61128.252963        28941.95

# %%
# Split train data to X and y
X_train = train_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_train = train_dataset.loc[:,['TOMORROW_CLOSE']]

# Split test data to X and y
X_test = test_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_test = test_dataset.loc[:,['TOMORROW_CLOSE']]

# %%
# Double check the X
X_train.head()
# Out:
#                  low      high      open        volume
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200

# %%
#Plot train and test data
fig1 = plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset.TOMORROW_CLOSE)
plt.plot(test_dataset.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
fig1.savefig('train_test_split.png')
# Out:
# Dimension of train data:  (490, 5)
# Dimension of test data:  (55, 5)

# %% [markdown]
# As we can observe, we have chosen the starting date to be 01/01/2021 because of the dynamic change in the price has started around this date, and so if the model will be able to predict the daynamic behaviour later, it has to be trained on similiar behaviour data. While, the data before this date is relatively steady, and didn't help the model the learn anything from. Matter fact, it lead to poor results.
# Below, is a plot of the bitcoin price evolution from 2012.

# %%
btc = HistoricalData('BTC-USD',86400,'2012-01-01-00-00', '2022-07-01-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2012-01-01T00:00:00
# Provisional End: 2012-10-27T00:00:00
# Data for chunk 1 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2012-01-01T00:00:00'
# Provisional Start: 2012-10-27T00:00:00
# Provisional End: 2013-08-23T00:00:00
# Data for chunk 2 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2012-10-27T00:00:00'
# Provisional Start: 2013-08-23T00:00:00
# Provisional End: 2014-06-19T00:00:00
# Data for chunk 3 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2013-08-23T00:00:00'
# Provisional Start: 2014-06-19T00:00:00
# Provisional End: 2015-04-15T00:00:00
# Data for chunk 4 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2014-06-19T00:00:00'
# Provisional Start: 2015-04-15T00:00:00
# Provisional End: 2016-02-09T00:00:00
# Data for chunk 5 of 13 extracted
# Provisional Start: 2016-02-09T00:00:00
# Provisional End: 2016-12-05T00:00:00
# Data for chunk 6 of 13 extracted
# Provisional Start: 2016-12-05T00:00:00
# Provisional End: 2017-10-01T00:00:00
# Data for chunk 7 of 13 extracted
# Provisional Start: 2017-10-01T00:00:00
# Provisional End: 2018-07-28T00:00:00
# Data for chunk 8 of 13 extracted
# Provisional Start: 2018-07-28T00:00:00
# Provisional End: 2019-05-24T00:00:00
# Data for chunk 9 of 13 extracted
# Provisional Start: 2019-05-24T00:00:00
# Provisional End: 2020-03-19T00:00:00
# Data for chunk 10 of 13 extracted
# Provisional Start: 2020-03-19T00:00:00
# Provisional End: 2021-01-13T00:00:00
# Data for chunk 11 of 13 extracted
# Provisional Start: 2021-01-13T00:00:00
# Provisional End: 2021-11-09T00:00:00
# Data for chunk 12 of 13 extracted
# Provisional Start: 2021-11-09T00:00:00
# Provisional End: 2022-09-05T00:00:00
# Data for chunk 13 of 13 extracted

# %%
# Create variable '‘TOMORROW_CLOSE’' which shifts 'Close' up by 1
btc['TOMORROW_CLOSE'] = btc['close'].shift(-1,fill_value=0)

# drop last row because we shifted value (remember this when you add your forecasting data)
btc.drop(btc.tail(1).index,inplace=True) 

# Drop close column, since we created new ‘TOMORROW_CLOSE’
btc = btc.drop(columns=['close'])

# Split the data intro train data (90%) and test data (10%)

train_size_1 = int(len(btc)*0.90)
train_dataset_1, test_dataset_1 = btc.iloc[:train_size_1],btc.iloc[train_size_1:]

# Split train data to X and y
X_train_1 = train_dataset_1.drop('TOMORROW_CLOSE', axis = 1)
y_train_1 = train_dataset_1.loc[:,['TOMORROW_CLOSE']]

# Split test data to X and y
X_test_1 = test_dataset_1.drop('TOMORROW_CLOSE', axis = 1)
y_test_1 = test_dataset_1.loc[:,['TOMORROW_CLOSE']]

# %%
#Plot train and test data
fig2 = plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset_1.TOMORROW_CLOSE)
plt.plot(test_dataset_1.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset_1.shape)
print('Dimension of test data: ', test_dataset_1.shape)
fig2.savefig('entire_train_test_data.png')
# Out:
# Dimension of train data:  (2284, 5)
# Dimension of test data:  (254, 5)

# %% [markdown]
# **Data Normalization**

# %%
# Different scaler for input and output ----> Normalizate the data
scaler_x = MinMaxScaler(feature_range = (-1,1))
scaler_y = MinMaxScaler(feature_range = (-1,1))

# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)

# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# %% [markdown]
# **Prepare the data to be fed into the model.
# Create 3 D tensor of data.**

# %%
# Create 3 dimensional data set 
def threeD_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
        
    return np.array(Xs), np.array(ys)


TIME_STEPS = 15 # which means the model will make predictions of ‘TOMORROW_CLOSE’ based on the input from the 10 previous days or future days bi-lstm or bi-gru

X_test, y_test = threeD_dataset(test_x_norm, test_y_norm, TIME_STEPS)
X_train, y_train = threeD_dataset(train_x_norm, train_y_norm, TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (475, 15, 4)
# y_train.shape:  (475, 1)
# X_test.shape:  (40, 15, 4)
# y_test.shape:  (40, 1)

# %% [markdown]
# **FINALLY, we can CONSTUCT the MODEL**

# %%
# Create LSTM 
def create_model(m):
    model = Sequential()
    # First layer of LSTM
    model.add(m (units = 64, activation = 'relu', return_sequences = False, input_shape = [X_train.shape[1], X_train.shape[2]])) # use 64 hidden units, relu acitvation function,
    # return_sequence is False, because we will use one layer LSTM
    # Add a dense layer
    model.add(Dense(units = 1))  # number of units is 1, because we will predict one output, which is tomorrow's price and compare it with the ground truth  
    model.compile(loss = 'mse', optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001 ) ) # use loss as MSE and Adam optimizer, with learning rate 0.000001
    return model

# %%
# Create the model by passing LSTM to the model.
model_lstm = create_model(LSTM)

# %%
# Let's check the summary of our baby model
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                17664
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 17,729
# Trainable params: 17,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
# start the  training process, with 800 epochs, (the number of times the model will look at the entire dataset), validation split is 20 % from the training data, this is
# done autmatically by Keras, batch size of 8, meaning that, the model will take try to minimize the loss by looking at only 8 samples, shuffle is false, because this is time 
# data, so the order matters alot.
history_lstm = model_lstm.fit(X_train, y_train, epochs = 1000, validation_split = 0.2,batch_size = 16, shuffle = False)
# Out:
# Epoch 1/1000
# 24/24 [==============================] - 4s 44ms/step - loss: 0.2696 - val_loss: 0.1700
# Epoch 2/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2668 - val_loss: 0.1682
# Epoch 3/1000
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2642 - val_loss: 0.1665
# Epoch 4/1000
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2615 - val_loss: 0.1647
# Epoch 5/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2588 - val_loss: 0.1630
# Epoch 6/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2562 - val_loss: 0.1613
# Epoch 7/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2536 - val_loss: 0.1595
# Epoch 8/1000
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2510 - val_loss: 0.1578
# Epoch 9/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2484 - val_loss: 0.1561
# Epoch 10/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2458 - val_loss: 0.1544
# Epoch 11/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2433 - val_loss: 0.1527
# Epoch 12/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2407 - val_loss: 0.1510
# Epoch 13/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2382 - val_loss: 0.1493
# Epoch 14/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2356 - val_loss: 0.1476
# Epoch 15/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2331 - val_loss: 0.1459
# Epoch 16/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2306 - val_loss: 0.1442
# Epoch 17/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2281 - val_loss: 0.1425
# Epoch 18/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2256 - val_loss: 0.1409
# Epoch 19/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2231 - val_loss: 0.1392
# Epoch 20/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2207 - val_loss: 0.1376
# Epoch 21/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2182 - val_loss: 0.1359
# Epoch 22/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2157 - val_loss: 0.1343
# Epoch 23/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2133 - val_loss: 0.1327
# Epoch 24/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2108 - val_loss: 0.1310
# Epoch 25/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2083 - val_loss: 0.1294
# Epoch 26/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2059 - val_loss: 0.1278
# Epoch 27/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2034 - val_loss: 0.1262
# Epoch 28/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2009 - val_loss: 0.1245
# Epoch 29/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1985 - val_loss: 0.1229
# Epoch 30/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1960 - val_loss: 0.1213
# Epoch 31/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1935 - val_loss: 0.1197
# Epoch 32/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1911 - val_loss: 0.1181
# Epoch 33/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1886 - val_loss: 0.1164
# Epoch 34/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1861 - val_loss: 0.1148
# Epoch 35/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1836 - val_loss: 0.1132
# Epoch 36/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1812 - val_loss: 0.1116
# Epoch 37/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1787 - val_loss: 0.1100
# Epoch 38/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1762 - val_loss: 0.1084
# Epoch 39/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1737 - val_loss: 0.1068
# Epoch 40/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1712 - val_loss: 0.1052
# Epoch 41/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1687 - val_loss: 0.1035
# Epoch 42/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1661 - val_loss: 0.1019
# Epoch 43/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1635 - val_loss: 0.1002
# Epoch 44/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1609 - val_loss: 0.0985
# Epoch 45/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1583 - val_loss: 0.0968
# Epoch 46/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1557 - val_loss: 0.0951
# Epoch 47/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1531 - val_loss: 0.0934
# Epoch 48/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1505 - val_loss: 0.0917
# Epoch 49/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1479 - val_loss: 0.0900
# Epoch 50/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1453 - val_loss: 0.0882
# Epoch 51/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1428 - val_loss: 0.0865
# Epoch 52/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1402 - val_loss: 0.0848
# Epoch 53/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1376 - val_loss: 0.0830
# Epoch 54/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1350 - val_loss: 0.0812
# Epoch 55/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1325 - val_loss: 0.0795
# Epoch 56/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1299 - val_loss: 0.0777
# Epoch 57/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1273 - val_loss: 0.0758
# Epoch 58/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1246 - val_loss: 0.0740
# Epoch 59/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1220 - val_loss: 0.0722
# Epoch 60/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1194 - val_loss: 0.0704
# Epoch 61/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1169 - val_loss: 0.0685
# Epoch 62/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1143 - val_loss: 0.0667
# Epoch 63/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1117 - val_loss: 0.0648
# Epoch 64/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1092 - val_loss: 0.0630
# Epoch 65/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1066 - val_loss: 0.0611
# Epoch 66/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1042 - val_loss: 0.0593
# Epoch 67/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1017 - val_loss: 0.0575
# Epoch 68/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0993 - val_loss: 0.0558
# Epoch 69/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0970 - val_loss: 0.0540
# Epoch 70/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0947 - val_loss: 0.0523
# Epoch 71/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0925 - val_loss: 0.0506
# Epoch 72/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0903 - val_loss: 0.0490
# Epoch 73/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0882 - val_loss: 0.0475
# Epoch 74/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0861 - val_loss: 0.0460
# Epoch 75/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0842 - val_loss: 0.0445
# Epoch 76/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0823 - val_loss: 0.0431
# Epoch 77/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0804 - val_loss: 0.0418
# Epoch 78/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0786 - val_loss: 0.0405
# Epoch 79/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0769 - val_loss: 0.0393
# Epoch 80/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0752 - val_loss: 0.0381
# Epoch 81/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0736 - val_loss: 0.0370
# Epoch 82/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0721 - val_loss: 0.0360
# Epoch 83/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0706 - val_loss: 0.0351
# Epoch 84/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0692 - val_loss: 0.0341
# Epoch 85/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0679 - val_loss: 0.0333
# Epoch 86/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0666 - val_loss: 0.0325
# Epoch 87/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0654 - val_loss: 0.0318
# Epoch 88/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0642 - val_loss: 0.0311
# Epoch 89/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0631 - val_loss: 0.0305
# Epoch 90/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0620 - val_loss: 0.0299
# Epoch 91/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0610 - val_loss: 0.0294
# Epoch 92/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0601 - val_loss: 0.0289
# Epoch 93/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0591 - val_loss: 0.0284
# Epoch 94/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0583 - val_loss: 0.0280
# Epoch 95/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0574 - val_loss: 0.0276
# Epoch 96/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0566 - val_loss: 0.0273
# Epoch 97/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0559 - val_loss: 0.0269
# Epoch 98/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0551 - val_loss: 0.0266
# Epoch 99/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0544 - val_loss: 0.0264
# Epoch 100/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0538 - val_loss: 0.0261
# Epoch 101/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0531 - val_loss: 0.0259
# Epoch 102/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0525 - val_loss: 0.0257
# Epoch 103/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0520 - val_loss: 0.0255
# Epoch 104/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0514 - val_loss: 0.0254
# Epoch 105/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0509 - val_loss: 0.0252
# Epoch 106/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0503 - val_loss: 0.0251
# Epoch 107/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0499 - val_loss: 0.0249
# Epoch 108/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0494 - val_loss: 0.0248
# Epoch 109/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0489 - val_loss: 0.0247
# Epoch 110/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0485 - val_loss: 0.0246
# Epoch 111/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0481 - val_loss: 0.0245
# Epoch 112/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0477 - val_loss: 0.0244
# Epoch 113/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0473 - val_loss: 0.0243
# Epoch 114/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0469 - val_loss: 0.0242
# Epoch 115/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0466 - val_loss: 0.0241
# Epoch 116/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0462 - val_loss: 0.0241
# Epoch 117/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0459 - val_loss: 0.0240
# Epoch 118/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0456 - val_loss: 0.0239
# Epoch 119/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0453 - val_loss: 0.0239
# Epoch 120/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0450 - val_loss: 0.0238
# Epoch 121/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0447 - val_loss: 0.0237
# Epoch 122/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0445 - val_loss: 0.0237
# Epoch 123/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0442 - val_loss: 0.0236
# Epoch 124/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0440 - val_loss: 0.0235
# Epoch 125/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0438 - val_loss: 0.0235
# Epoch 126/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0436 - val_loss: 0.0234
# Epoch 127/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0434 - val_loss: 0.0234
# Epoch 128/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0432 - val_loss: 0.0233
# Epoch 129/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0430 - val_loss: 0.0232
# Epoch 130/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0428 - val_loss: 0.0232
# Epoch 131/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0426 - val_loss: 0.0231
# Epoch 132/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0425 - val_loss: 0.0231
# Epoch 133/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0423 - val_loss: 0.0230
# Epoch 134/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0421 - val_loss: 0.0230
# Epoch 135/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0420 - val_loss: 0.0229
# Epoch 136/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0419 - val_loss: 0.0228
# Epoch 137/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0417 - val_loss: 0.0228
# Epoch 138/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0416 - val_loss: 0.0227
# Epoch 139/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0415 - val_loss: 0.0227
# Epoch 140/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0414 - val_loss: 0.0226
# Epoch 141/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0413 - val_loss: 0.0225
# Epoch 142/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0411 - val_loss: 0.0225
# Epoch 143/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0410 - val_loss: 0.0224
# Epoch 144/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0409 - val_loss: 0.0224
# Epoch 145/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0408 - val_loss: 0.0223
# Epoch 146/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0407 - val_loss: 0.0222
# Epoch 147/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0406 - val_loss: 0.0222
# Epoch 148/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0406 - val_loss: 0.0221
# Epoch 149/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0405 - val_loss: 0.0221
# Epoch 150/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0404 - val_loss: 0.0220
# Epoch 151/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0403 - val_loss: 0.0220
# Epoch 152/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0402 - val_loss: 0.0219
# Epoch 153/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0401 - val_loss: 0.0218
# Epoch 154/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0401 - val_loss: 0.0218
# Epoch 155/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0400 - val_loss: 0.0217
# Epoch 156/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0399 - val_loss: 0.0217
# Epoch 157/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0398 - val_loss: 0.0216
# Epoch 158/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0398 - val_loss: 0.0216
# Epoch 159/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0215
# Epoch 160/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0396 - val_loss: 0.0214
# Epoch 161/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0395 - val_loss: 0.0214
# Epoch 162/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0395 - val_loss: 0.0213
# Epoch 163/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0394 - val_loss: 0.0213
# Epoch 164/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0393 - val_loss: 0.0212
# Epoch 165/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0393 - val_loss: 0.0212
# Epoch 166/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0392 - val_loss: 0.0211
# Epoch 167/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0392 - val_loss: 0.0211
# Epoch 168/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0391 - val_loss: 0.0210
# Epoch 169/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0390 - val_loss: 0.0210
# Epoch 170/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0390 - val_loss: 0.0209
# Epoch 171/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0389 - val_loss: 0.0209
# Epoch 172/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0388 - val_loss: 0.0208
# Epoch 173/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0388 - val_loss: 0.0208
# Epoch 174/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0387 - val_loss: 0.0207
# Epoch 175/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0387 - val_loss: 0.0207
# Epoch 176/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0386 - val_loss: 0.0206
# Epoch 177/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0386 - val_loss: 0.0206
# Epoch 178/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0385 - val_loss: 0.0205
# Epoch 179/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0384 - val_loss: 0.0205
# Epoch 180/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0384 - val_loss: 0.0205
# Epoch 181/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0383 - val_loss: 0.0204
# Epoch 182/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0383 - val_loss: 0.0204
# Epoch 183/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0382 - val_loss: 0.0203
# Epoch 184/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0382 - val_loss: 0.0203
# Epoch 185/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0381 - val_loss: 0.0202
# Epoch 186/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0380 - val_loss: 0.0202
# Epoch 187/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0380 - val_loss: 0.0201
# Epoch 188/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0379 - val_loss: 0.0201
# Epoch 189/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0379 - val_loss: 0.0201
# Epoch 190/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0378 - val_loss: 0.0200
# Epoch 191/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0378 - val_loss: 0.0200
# Epoch 192/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0377 - val_loss: 0.0199
# Epoch 193/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0377 - val_loss: 0.0199
# Epoch 194/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0376 - val_loss: 0.0199
# Epoch 195/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0375 - val_loss: 0.0198
# Epoch 196/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0375 - val_loss: 0.0198
# Epoch 197/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0374 - val_loss: 0.0198
# Epoch 198/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0374 - val_loss: 0.0197
# Epoch 199/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0373 - val_loss: 0.0197
# Epoch 200/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0373 - val_loss: 0.0196
# Epoch 201/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0372 - val_loss: 0.0196
# Epoch 202/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0372 - val_loss: 0.0196
# Epoch 203/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0371 - val_loss: 0.0195
# Epoch 204/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0370 - val_loss: 0.0195
# Epoch 205/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0370 - val_loss: 0.0195
# Epoch 206/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0369 - val_loss: 0.0194
# Epoch 207/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0369 - val_loss: 0.0194
# Epoch 208/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0368 - val_loss: 0.0194
# Epoch 209/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0368 - val_loss: 0.0194
# Epoch 210/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0367 - val_loss: 0.0193
# Epoch 211/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0366 - val_loss: 0.0193
# Epoch 212/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0366 - val_loss: 0.0193
# Epoch 213/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0365 - val_loss: 0.0192
# Epoch 214/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0365 - val_loss: 0.0192
# Epoch 215/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0364 - val_loss: 0.0192
# Epoch 216/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0363 - val_loss: 0.0191
# Epoch 217/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0363 - val_loss: 0.0191
# Epoch 218/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0362 - val_loss: 0.0191
# Epoch 219/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0362 - val_loss: 0.0190
# Epoch 220/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0361 - val_loss: 0.0190
# Epoch 221/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0360 - val_loss: 0.0190
# Epoch 222/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0360 - val_loss: 0.0190
# Epoch 223/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0359 - val_loss: 0.0189
# Epoch 224/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0359 - val_loss: 0.0189
# Epoch 225/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0358 - val_loss: 0.0189
# Epoch 226/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0357 - val_loss: 0.0188
# Epoch 227/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0357 - val_loss: 0.0188
# Epoch 228/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0356 - val_loss: 0.0188
# Epoch 229/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0356 - val_loss: 0.0188
# Epoch 230/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0355 - val_loss: 0.0187
# Epoch 231/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0354 - val_loss: 0.0187
# Epoch 232/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0354 - val_loss: 0.0187
# Epoch 233/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0353 - val_loss: 0.0187
# Epoch 234/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0353 - val_loss: 0.0186
# Epoch 235/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0352 - val_loss: 0.0186
# Epoch 236/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0351 - val_loss: 0.0186
# Epoch 237/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0351 - val_loss: 0.0186
# Epoch 238/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0350 - val_loss: 0.0186
# Epoch 239/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0349 - val_loss: 0.0185
# Epoch 240/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0349 - val_loss: 0.0185
# Epoch 241/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0348 - val_loss: 0.0185
# Epoch 242/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0348 - val_loss: 0.0185
# Epoch 243/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0347 - val_loss: 0.0184
# Epoch 244/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0346 - val_loss: 0.0184
# Epoch 245/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0346 - val_loss: 0.0184
# Epoch 246/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0345 - val_loss: 0.0184
# Epoch 247/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0345 - val_loss: 0.0184
# Epoch 248/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0344 - val_loss: 0.0183
# Epoch 249/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0343 - val_loss: 0.0183
# Epoch 250/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0343 - val_loss: 0.0183
# Epoch 251/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0342 - val_loss: 0.0183
# Epoch 252/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0342 - val_loss: 0.0183
# Epoch 253/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0341 - val_loss: 0.0182
# Epoch 254/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0341 - val_loss: 0.0182
# Epoch 255/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0340 - val_loss: 0.0182
# Epoch 256/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0339 - val_loss: 0.0182
# Epoch 257/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0339 - val_loss: 0.0182
# Epoch 258/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0338 - val_loss: 0.0182
# Epoch 259/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0338 - val_loss: 0.0181
# Epoch 260/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0337 - val_loss: 0.0181
# Epoch 261/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0337 - val_loss: 0.0181
# Epoch 262/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0336 - val_loss: 0.0181
# Epoch 263/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0336 - val_loss: 0.0181
# Epoch 264/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0335 - val_loss: 0.0181
# Epoch 265/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0334 - val_loss: 0.0180
# Epoch 266/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0334 - val_loss: 0.0180
# Epoch 267/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0333 - val_loss: 0.0180
# Epoch 268/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0333 - val_loss: 0.0180
# Epoch 269/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0332 - val_loss: 0.0180
# Epoch 270/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0332 - val_loss: 0.0180
# Epoch 271/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0331 - val_loss: 0.0179
# Epoch 272/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0331 - val_loss: 0.0179
# Epoch 273/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0179
# Epoch 274/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0179
# Epoch 275/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0329 - val_loss: 0.0179
# Epoch 276/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0329 - val_loss: 0.0179
# Epoch 277/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0328 - val_loss: 0.0179
# Epoch 278/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0328 - val_loss: 0.0178
# Epoch 279/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0327 - val_loss: 0.0178
# Epoch 280/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0327 - val_loss: 0.0178
# Epoch 281/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0326 - val_loss: 0.0178
# Epoch 282/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0326 - val_loss: 0.0178
# Epoch 283/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0325 - val_loss: 0.0178
# Epoch 284/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0325 - val_loss: 0.0178
# Epoch 285/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0324 - val_loss: 0.0178
# Epoch 286/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0324 - val_loss: 0.0177
# Epoch 287/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0324 - val_loss: 0.0177
# Epoch 288/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0323 - val_loss: 0.0177
# Epoch 289/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0323 - val_loss: 0.0177
# Epoch 290/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0322 - val_loss: 0.0177
# Epoch 291/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0322 - val_loss: 0.0177
# Epoch 292/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0321 - val_loss: 0.0177
# Epoch 293/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0321 - val_loss: 0.0177
# Epoch 294/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0321 - val_loss: 0.0176
# Epoch 295/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0320 - val_loss: 0.0176
# Epoch 296/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0320 - val_loss: 0.0176
# Epoch 297/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0319 - val_loss: 0.0176
# Epoch 298/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0319 - val_loss: 0.0176
# Epoch 299/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0318 - val_loss: 0.0176
# Epoch 300/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0318 - val_loss: 0.0176
# Epoch 301/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0318 - val_loss: 0.0176
# Epoch 302/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0317 - val_loss: 0.0175
# Epoch 303/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0317 - val_loss: 0.0175
# Epoch 304/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0316 - val_loss: 0.0175
# Epoch 305/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0316 - val_loss: 0.0175
# Epoch 306/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0316 - val_loss: 0.0175
# Epoch 307/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0315 - val_loss: 0.0175
# Epoch 308/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0315 - val_loss: 0.0175
# Epoch 309/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0314 - val_loss: 0.0175
# Epoch 310/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0314 - val_loss: 0.0174
# Epoch 311/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0314 - val_loss: 0.0174
# Epoch 312/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0313 - val_loss: 0.0174
# Epoch 313/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0313 - val_loss: 0.0174
# Epoch 314/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0313 - val_loss: 0.0174
# Epoch 315/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0312 - val_loss: 0.0174
# Epoch 316/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0312 - val_loss: 0.0174
# Epoch 317/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0311 - val_loss: 0.0174
# Epoch 318/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0311 - val_loss: 0.0174
# Epoch 319/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0311 - val_loss: 0.0173
# Epoch 320/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0310 - val_loss: 0.0173
# Epoch 321/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0310 - val_loss: 0.0173
# Epoch 322/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0310 - val_loss: 0.0173
# Epoch 323/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0309 - val_loss: 0.0173
# Epoch 324/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0309 - val_loss: 0.0173
# Epoch 325/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0309 - val_loss: 0.0173
# Epoch 326/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0308 - val_loss: 0.0173
# Epoch 327/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0308 - val_loss: 0.0173
# Epoch 328/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0308 - val_loss: 0.0173
# Epoch 329/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0307 - val_loss: 0.0172
# Epoch 330/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0307 - val_loss: 0.0172
# Epoch 331/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0307 - val_loss: 0.0172
# Epoch 332/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0306 - val_loss: 0.0172
# Epoch 333/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0306 - val_loss: 0.0172
# Epoch 334/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0306 - val_loss: 0.0172
# Epoch 335/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0305 - val_loss: 0.0172
# Epoch 336/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0305 - val_loss: 0.0172
# Epoch 337/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0305 - val_loss: 0.0172
# Epoch 338/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0305 - val_loss: 0.0172
# Epoch 339/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0304 - val_loss: 0.0172
# Epoch 340/1000
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0304 - val_loss: 0.0171
# Epoch 341/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0304 - val_loss: 0.0171
# Epoch 342/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.0171
# Epoch 343/1000
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0303 - val_loss: 0.0171
# Epoch 344/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0303 - val_loss: 0.0171
# Epoch 345/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.0171
# Epoch 346/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0302 - val_loss: 0.0171
# Epoch 347/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0302 - val_loss: 0.0171
# Epoch 348/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0302 - val_loss: 0.0171
# Epoch 349/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0302 - val_loss: 0.0171
# Epoch 350/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.0171
# Epoch 351/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0301 - val_loss: 0.0171
# Epoch 352/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.0170
# Epoch 353/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0301 - val_loss: 0.0170
# Epoch 354/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0300 - val_loss: 0.0170
# Epoch 355/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0300 - val_loss: 0.0170
# Epoch 356/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0300 - val_loss: 0.0170
# Epoch 357/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0300 - val_loss: 0.0170
# Epoch 358/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0299 - val_loss: 0.0170
# Epoch 359/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0299 - val_loss: 0.0170
# Epoch 360/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0299 - val_loss: 0.0170
# Epoch 361/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0299 - val_loss: 0.0170
# Epoch 362/1000
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0299 - val_loss: 0.0170
# Epoch 363/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0298 - val_loss: 0.0170
# Epoch 364/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0298 - val_loss: 0.0169
# Epoch 365/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0298 - val_loss: 0.0169
# Epoch 366/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0298 - val_loss: 0.0169
# Epoch 367/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0297 - val_loss: 0.0169
# Epoch 368/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0297 - val_loss: 0.0169
# Epoch 369/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0297 - val_loss: 0.0169
# Epoch 370/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0297 - val_loss: 0.0169
# Epoch 371/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0297 - val_loss: 0.0169
# Epoch 372/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0296 - val_loss: 0.0169
# Epoch 373/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0296 - val_loss: 0.0169
# Epoch 374/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0296 - val_loss: 0.0169
# Epoch 375/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0296 - val_loss: 0.0169
# Epoch 376/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0296 - val_loss: 0.0169
# Epoch 377/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0295 - val_loss: 0.0168
# Epoch 378/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0295 - val_loss: 0.0168
# Epoch 379/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0295 - val_loss: 0.0168
# Epoch 380/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0295 - val_loss: 0.0168
# Epoch 381/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0295 - val_loss: 0.0168
# Epoch 382/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0168
# Epoch 383/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0168
# Epoch 384/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0294 - val_loss: 0.0168
# Epoch 385/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0294 - val_loss: 0.0168
# Epoch 386/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0168
# Epoch 387/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0293 - val_loss: 0.0168
# Epoch 388/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0168
# Epoch 389/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0168
# Epoch 390/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0168
# Epoch 391/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0168
# Epoch 392/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0167
# Epoch 393/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 394/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 395/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 396/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 397/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 398/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.0167
# Epoch 399/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0291 - val_loss: 0.0167
# Epoch 400/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0291 - val_loss: 0.0167
# Epoch 401/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0291 - val_loss: 0.0167
# Epoch 402/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0291 - val_loss: 0.0167
# Epoch 403/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0291 - val_loss: 0.0167
# Epoch 404/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0290 - val_loss: 0.0167
# Epoch 405/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0290 - val_loss: 0.0167
# Epoch 406/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0290 - val_loss: 0.0167
# Epoch 407/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0290 - val_loss: 0.0167
# Epoch 408/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.0167
# Epoch 409/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0290 - val_loss: 0.0166
# Epoch 410/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 411/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 412/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 413/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 414/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 415/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0289 - val_loss: 0.0166
# Epoch 416/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 417/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 418/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 419/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 420/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 421/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.0166
# Epoch 422/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0166
# Epoch 423/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0287 - val_loss: 0.0166
# Epoch 424/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0166
# Epoch 425/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0166
# Epoch 426/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0287 - val_loss: 0.0165
# Epoch 427/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0287 - val_loss: 0.0165
# Epoch 428/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0286 - val_loss: 0.0165
# Epoch 429/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0286 - val_loss: 0.0165
# Epoch 430/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0286 - val_loss: 0.0165
# Epoch 431/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0286 - val_loss: 0.0165
# Epoch 432/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0286 - val_loss: 0.0165
# Epoch 433/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 434/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 435/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 436/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 437/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 438/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 439/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.0165
# Epoch 440/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.0165
# Epoch 441/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.0165
# Epoch 442/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0284 - val_loss: 0.0165
# Epoch 443/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0284 - val_loss: 0.0164
# Epoch 444/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.0164
# Epoch 445/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.0164
# Epoch 446/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 447/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 448/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 449/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 450/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 451/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.0164
# Epoch 452/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 453/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 454/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 455/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 456/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 457/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 458/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 459/1000
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0281 - val_loss: 0.0164
# Epoch 460/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0281 - val_loss: 0.0163
# Epoch 461/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0281 - val_loss: 0.0163
# Epoch 462/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0281 - val_loss: 0.0163
# Epoch 463/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0281 - val_loss: 0.0163
# Epoch 464/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0281 - val_loss: 0.0163
# Epoch 465/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.0163
# Epoch 466/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.0163
# Epoch 467/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.0163
# ...
# Epoch 846/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 847/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 848/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 849/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 850/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 851/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 852/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0148
# Epoch 853/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 854/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 855/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 856/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 857/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 858/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 859/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 860/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 861/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 862/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 863/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 864/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0148
# Epoch 865/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0148
# Epoch 866/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0148
# Epoch 867/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 868/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 869/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 870/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 871/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 872/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 873/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 874/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 875/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 876/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.0147
# Epoch 877/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 878/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 879/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 880/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 881/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 882/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 883/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 884/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 885/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 886/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 887/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 888/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.0147
# Epoch 889/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 890/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 891/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 892/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 893/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 894/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 895/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 896/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 897/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 898/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 899/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 900/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0147
# Epoch 901/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 902/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 903/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 904/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 905/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 906/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 907/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 908/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 909/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 910/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 911/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 912/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 913/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0147
# Epoch 914/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 915/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 916/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 917/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 918/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 919/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 920/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 921/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 922/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0147
# Epoch 923/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0232 - val_loss: 0.0146
# Epoch 924/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0146
# Epoch 925/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.0146
# Epoch 926/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 927/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 928/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 929/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 930/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 931/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 932/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 933/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 934/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 935/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 936/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 937/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 938/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.0146
# Epoch 939/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 940/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 941/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 942/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 943/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 944/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 945/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 946/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 947/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 948/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 949/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 950/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 951/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0146
# Epoch 952/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 953/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 954/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 955/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 956/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 957/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 958/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 959/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 960/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 961/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 962/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 963/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 964/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0146
# Epoch 965/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 966/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 967/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 968/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 969/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 970/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 971/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 972/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 973/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 974/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 975/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 976/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 977/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 978/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0146
# Epoch 979/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 980/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 981/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 982/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 983/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 984/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 985/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 986/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 987/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 988/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 989/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 990/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 991/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 992/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0146
# Epoch 993/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 994/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 995/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 996/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 997/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 998/1000
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 999/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.0146
# Epoch 1000/1000
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.0146

# %% [markdown]
# As we can observe, the loss is the training loss, and val_loss is the validation loss. Both are decereasing smoothly as the number of epochs is increasing, that means, our **model is learning in a natural way**.
#
# Next, **let's plot the validation and train error**, to check for any problems that a model can suffer from, such as underfitting or overfitting.

# %%
#Plot train and validation loss
def plot_loss (history, model_name):
    fig3 = plt.figure(figsize = (10, 6))
    plt.rcParams['figure.dpi'] = 360
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    fig3.savefig('Model_Train_vs_Validation_Loss_for_LSTM.png')
plot_loss (history_lstm, 'LSTM')

# %% [markdown]
# Before we start the testing phase, we need to inverse the normalization process that we applied to the data.

# %%
# inverse the y
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# %% [markdown]
# Define a function to inverse the X

# %%
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction

# %%
# Do predictions
prediction_LSTM = prediction(model_lstm)

# %%
def plot_future(prediction, model_name, y_test):
    
    fig4 = plt.figure(figsize=(10, 6))
    plt.rcParams['figure.dpi'] = 360
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='True Future')
    plt.plot(np.arange(range_future), np.array(prediction),label='Prediction')

    plt.title('True future vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Date')
    plt.ylabel('Close value (USD $)')
    fig4.savefig('True_future_vs_prediction_for_LSTM.png')
plot_future(prediction_LSTM, 'LSTM', y_test)

# %%
y_test.shape
# Out:
# (40, 1)

# %%
## Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()

    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

# %%
evaluate_prediction(prediction_LSTM, y_test, 'LSTM')
# Out:
# LSTM:
# Mean Absolute Error: 1930.7062
# Root Mean Square Error: 2687.9827
