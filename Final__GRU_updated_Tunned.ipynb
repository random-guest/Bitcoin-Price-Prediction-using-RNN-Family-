# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
sns.set_style("white")
import scipy 
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from IPython.core.pylabtools import figsize
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from keras.layers import *
from keras.models import *
from keras import backend as K
# Set random seed for reproducibility
tf.random.set_seed(42)

# %%
# !pip install Historic-Crypto
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Historic-Crypto in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (1.24.3)

# %%
import warnings
warnings.filterwarnings("ignore")

from Historic_Crypto import HistoricalData

# %%
btc_historicals = HistoricalData('BTC-USD',86400,'2021-01-01-00-00', '2022-07-01-00-00').retrieve_data() # cyrpto name, number of seconds, start date, end date
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-01-01T00:00:00
# Provisional End: 2021-10-28T00:00:00
# Data for chunk 1 of 2 extracted
# Provisional Start: 2021-10-28T00:00:00
# Provisional End: 2022-08-24T00:00:00
# Data for chunk 2 of 2 extracted

# %%
btc_historicals.shape
# Out:
# (546, 5)

# %%
btc_historicals.tail()
# Out:
#                  low      high      open     close        volume
# time
# 2022-06-27  20500.00  21520.00  21024.85  20725.17  17440.942683
# 2022-06-28  20164.70  21189.99  20722.95  20252.89  17658.660417
# 2022-06-29  19823.43  20410.91  20253.50  20094.79  18278.451859
# 2022-06-30  18603.00  20143.53  20098.00  19985.62  28361.458762
# 2022-07-01  18938.33  20879.99  19985.62  19252.76  32977.000523

# %%
# Check out variables
btc_historicals.dtypes
# Out:
# low       float64
# high      float64
# open      float64
# close     float64
# volume    float64
# dtype: object

# %%
tst = btc_historicals

# %%
print('Null Values:',tst.isnull().values.sum())
print('If any NA values:', tst.isnull().values.any())
# Out:
# Null Values: 0
# If any NA values: False

# %%
# Create variable '‘TOMORROW_CLOSE’' which shifts 'Close' up by 1
tst['TOMORROW_CLOSE'] = tst['close'].shift(-1,fill_value=0)

# %%
# drop last row because we shifted value (remember this when you add your forecasting data)
tst.drop(tst.tail(1).index,inplace=True)

# %%
# Drop close column, since we created new ‘TOMORROW_CLOSE’
tst = tst.drop(columns=['close'])

# %%
tst.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
tst.shape
# Out:
# (545, 5)

# %%
# Split train data (90%) and test data (10%)

train_size = int(len(tst)*0.90)
train_dataset, test_dataset = tst.iloc[:train_size],tst.iloc[train_size:]

# %%
train_dataset.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
# Split train data to X and y
X_train = train_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_train = train_dataset.loc[:,['TOMORROW_CLOSE']]

# Split test data to X and y
X_test = test_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_test = test_dataset.loc[:,['TOMORROW_CLOSE']]

# %%
X_train.head()
# Out:
#                  low      high      open        volume
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200

# %%
'''
#Plot train and test data
plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset.TOMORROW_CLOSE)
plt.plot(test_dataset.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
'''
# Out:
# "\n#Plot train and test data\nplt.figure(figsize = (12, 6))\nplt.rcParams['figure.dpi'] = 360\nplt.plot(train_dataset.TOMORROW_CLOSE)\nplt.plot(test_dataset.TOMORROW_CLOSE)\nplt.xlabel('Date')\nplt.ylabel('Close value (US$)')\nplt.legend(['Train set', 'Test set'], loc='upper left')\nprint('Dimension of train data: ',train_dataset.shape)\nprint('Dimension of test data: ', test_dataset.shape)\n"

# %%
# Different scaler for input and output ----> Normalizate the data
scaler_x = MinMaxScaler(feature_range = (-1,1))
scaler_y = MinMaxScaler(feature_range = (-1,1))

# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)

# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# %%
# Create 3 dimensional data set 
def threeD_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
        
    return np.array(Xs), np.array(ys)


TIME_STEPS = 15 # which means the model will make predictions of ‘TOMORROW_CLOSE’ based on the input from the 10 previous days or future days bi-lstm or bi-gru

X_test, y_test = threeD_dataset(test_x_norm, test_y_norm, TIME_STEPS)
X_train, y_train = threeD_dataset(train_x_norm, train_y_norm, TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (475, 15, 4)
# y_train.shape:  (475, 1)
# X_test.shape:  (40, 15, 4)
# y_test.shape:  (40, 1)

# %%
# Create gru 
def create_model(m):
    model = Sequential()
    # First layer of gru
    model.add(m (units = 32, activation = 'relu', return_sequences = False, input_shape = [X_train.shape[1], X_train.shape[2]])) # use 64 hidden units
    model.add(Dense(units = 1))
    model.compile(loss = 'mse', optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001 ) ) # use loss as MSE and Adam optimizer (0.001)
    return model

# %%
model_GRU = create_model(GRU)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Let's check the summary of our baby model
model_GRU.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32)                3648
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 3,681
# Trainable params: 3,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_gru = model_GRU.fit(X_train, y_train, epochs = 80, validation_split = 0.2,batch_size = 32, shuffle = False) # no shuffer , as its time series data (32) 80 epoch
# Out:
# Epoch 1/80
# 12/12 [==============================] - 3s 56ms/step - loss: 0.3099 - val_loss: 0.0602
# Epoch 2/80
# 12/12 [==============================] - 1s 50ms/step - loss: 0.2132 - val_loss: 0.0289
# Epoch 3/80
# 12/12 [==============================] - 1s 75ms/step - loss: 0.1468 - val_loss: 0.0163
# Epoch 4/80
# 12/12 [==============================] - 1s 75ms/step - loss: 0.1002 - val_loss: 0.0134
# Epoch 5/80
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0698 - val_loss: 0.0135
# Epoch 6/80
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0508 - val_loss: 0.0145
# Epoch 7/80
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0402 - val_loss: 0.0156
# Epoch 8/80
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0347 - val_loss: 0.0159
# Epoch 9/80
# 12/12 [==============================] - 1s 69ms/step - loss: 0.0319 - val_loss: 0.0157
# Epoch 10/80
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0301 - val_loss: 0.0152
# Epoch 11/80
# 12/12 [==============================] - 1s 79ms/step - loss: 0.0286 - val_loss: 0.0148
# Epoch 12/80
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0275 - val_loss: 0.0144
# Epoch 13/80
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0265 - val_loss: 0.0141
# Epoch 14/80
# 12/12 [==============================] - 1s 74ms/step - loss: 0.0257 - val_loss: 0.0138
# Epoch 15/80
# 12/12 [==============================] - 1s 69ms/step - loss: 0.0251 - val_loss: 0.0136
# Epoch 16/80
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0245 - val_loss: 0.0135
# Epoch 17/80
# 12/12 [==============================] - 1s 74ms/step - loss: 0.0240 - val_loss: 0.0133
# Epoch 18/80
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0236 - val_loss: 0.0132
# Epoch 19/80
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0232 - val_loss: 0.0131
# Epoch 20/80
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0228 - val_loss: 0.0131
# Epoch 21/80
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0225 - val_loss: 0.0131
# Epoch 22/80
# 12/12 [==============================] - 1s 94ms/step - loss: 0.0222 - val_loss: 0.0130
# Epoch 23/80
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0219 - val_loss: 0.0130
# Epoch 24/80
# 12/12 [==============================] - 1s 67ms/step - loss: 0.0217 - val_loss: 0.0129
# Epoch 25/80
# 12/12 [==============================] - 1s 71ms/step - loss: 0.0215 - val_loss: 0.0129
# Epoch 26/80
# 12/12 [==============================] - 1s 68ms/step - loss: 0.0213 - val_loss: 0.0129
# Epoch 27/80
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0211 - val_loss: 0.0128
# Epoch 28/80
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0209 - val_loss: 0.0128
# Epoch 29/80
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0208 - val_loss: 0.0128
# Epoch 30/80
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0207 - val_loss: 0.0128
# Epoch 31/80
# 12/12 [==============================] - 1s 42ms/step - loss: 0.0206 - val_loss: 0.0128
# Epoch 32/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0205 - val_loss: 0.0128
# Epoch 33/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0204 - val_loss: 0.0128
# Epoch 34/80
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0203 - val_loss: 0.0127
# Epoch 35/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0202 - val_loss: 0.0127
# Epoch 36/80
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0201 - val_loss: 0.0127
# Epoch 37/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0201 - val_loss: 0.0127
# Epoch 38/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0200 - val_loss: 0.0127
# Epoch 39/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0200 - val_loss: 0.0127
# Epoch 40/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0199 - val_loss: 0.0127
# Epoch 41/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0199 - val_loss: 0.0127
# Epoch 42/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0198 - val_loss: 0.0127
# Epoch 43/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0198 - val_loss: 0.0127
# Epoch 44/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0197 - val_loss: 0.0126
# Epoch 45/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0197 - val_loss: 0.0126
# Epoch 46/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0196 - val_loss: 0.0126
# Epoch 47/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0196 - val_loss: 0.0126
# Epoch 48/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0196 - val_loss: 0.0126
# Epoch 49/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0195 - val_loss: 0.0126
# Epoch 50/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0195 - val_loss: 0.0126
# Epoch 51/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0194 - val_loss: 0.0126
# Epoch 52/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0194 - val_loss: 0.0126
# Epoch 53/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0194 - val_loss: 0.0126
# Epoch 54/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0193 - val_loss: 0.0126
# Epoch 55/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0193 - val_loss: 0.0126
# Epoch 56/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0192 - val_loss: 0.0126
# Epoch 57/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0192 - val_loss: 0.0126
# Epoch 58/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0192 - val_loss: 0.0126
# Epoch 59/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0192 - val_loss: 0.0126
# Epoch 60/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0191 - val_loss: 0.0126
# Epoch 61/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0191 - val_loss: 0.0126
# Epoch 62/80
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0191 - val_loss: 0.0126
# Epoch 63/80
# 12/12 [==============================] - 0s 40ms/step - loss: 0.0191 - val_loss: 0.0126
# Epoch 64/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0190 - val_loss: 0.0126
# Epoch 65/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0190 - val_loss: 0.0126
# Epoch 66/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0190 - val_loss: 0.0126
# Epoch 67/80
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0190 - val_loss: 0.0126
# Epoch 68/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0190 - val_loss: 0.0126
# Epoch 69/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 70/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 71/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 72/80
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 73/80
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 74/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 75/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0189 - val_loss: 0.0126
# Epoch 76/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 77/80
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 78/80
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 79/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 80/80
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0188 - val_loss: 0.0126

# %%
#Plot train and validation loss
def plot_loss (history, model_name):
    fig1 = plt.figure(figsize = (10, 6))
    plt.rcParams['figure.dpi'] = 360
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    fig1.savefig('Model_Train_Validation_loss_GRU.png')
plot_loss (history_gru, 'GRU')

# %% [markdown]
# **Afte 30 epochs, the validation errors starts to rise, which is a sign of over fitting, therefore, one has to stop the training process at 30 epochs.**

# %%
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# %%
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction

# %%
prediction_gru = prediction(model_GRU)

# %%
def plot_future(prediction, model_name, y_test):
    fig4 = plt.figure(figsize=(10, 6))
    plt.rcParams['figure.dpi'] = 360
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), label='True Future')
    plt.plot(np.arange(range_future), np.array(prediction),label='Prediction')
    plt.title('True future vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Date')
    plt.ylabel('Close value (USD $)')
    fig4.savefig('True_future_vs_prediction_for_GRU.png')
plot_future(prediction_gru, 'GRU', y_test)

# %%
## Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

# %%
evaluate_prediction(prediction_gru, y_test, 'GRU')
# Out:
# GRU:
# Mean Absolute Error: 2459.8828
# Root Mean Square Error: 2950.3582
