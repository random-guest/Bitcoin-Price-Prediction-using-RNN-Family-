# %% [markdown]
# #Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
sns.set_style("white")

import scipy 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Conv2D,Conv1D

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from IPython.core.pylabtools import figsize

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import *
from keras.models import *
from keras import backend as K

# Set random seed for reproducibility
tf.random.set_seed(42)

# %% [markdown]
# ## Import the Data
# In this case, we will need to reach the data from the google drive.
# Therefore, please upload the data into your drive, and connect the drive
# to this notebook using this chunk of code.
# Perhaps you need to pay attention to the exact location of the data in your drive.

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
df = pd.read_csv('gdrive/My Drive/Colab_Notebooks/Bitcoin_price.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Check the Data

# %% [markdown]
# # Note on Data:
# The data is in the form of Date-open-high-low-close-volume-marketCap.
# It is colected between April 2013 and January 2021.
# The data is clean and has no NA's or Missing parts.
# After building and testing the models, we will include the data up to date for final testing.

# %%
df.tail()
# Out:
#            Date      Open      High       Low     Close        Volume  \
# 2811  08-Jan-21  39381.77  41946.74  36838.64  40797.61  8.810752e+10
# 2812  09-Jan-21  40788.64  41436.35  38980.88  40254.55  6.198416e+10
# 2813  10-Jan-21  40254.22  41420.19  35984.63  38356.44  7.998075e+10
# 2814  11-Jan-21  38346.53  38346.53  30549.60  35566.66  1.233210e+11
# 2815  12-Jan-21  35516.36  36568.53  32697.98  33922.96  7.477328e+10
#
#          MarketCap
# 2811  7.590000e+11
# 2812  7.490000e+11
# 2813  7.130000e+11
# 2814  6.614570e+11
# 2815  6.309200e+11

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close  Volume     MarketCap
# 0  29-Apr-13  134.44  147.49  134.00  144.54     0.0  1.603769e+09
# 1  30-Apr-13  144.00  146.93  134.05  139.00     0.0  1.542813e+09
# 2  01-May-13  139.00  139.89  107.72  116.99     0.0  1.298955e+09
# 3  02-May-13  116.38  125.60   92.28  105.21     0.0  1.168517e+09
# 4  03-May-13  106.25  108.13   79.10   97.75     0.0  1.085995e+09

# %% [markdown]
# ## Check the Variables' Type.

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# MarketCap    float64
# dtype: object

# %%
# We notice that the date is in the form of Object, and that's something we dont want.
# so we have to convert it to datetime
df['Date'] = df['Date'].astype('datetime64[ns]')

# %%
#Double check again
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume              float64
# MarketCap           float64
# dtype: object

# %% [markdown]
# ## What we are interested in is predicting tomorrow's closing price.
# Let's prepare the data for this.

# %%
# Create variable 'TOMORROW_CLOSE' which shifts 'Close' up by 1
df['TOMORROW_CLOSE'] = df['Close'].shift(-1,fill_value=0)

# %%
# drop last row because we shifted value (we should remember to do the same this when we add our forecasting new data)
df.drop(df.tail(1).index,inplace=True)

# %%
df = df.drop(columns=['Close'])

# %%
df = df.set_index('Date')

# %%
df.tail()
# Out:
#                 Open      High       Low        Volume     MarketCap  \
# Date
# 2021-01-07  36833.87  40180.37  36491.19  8.476214e+10  7.320000e+11
# 2021-01-08  39381.77  41946.74  36838.64  8.810752e+10  7.590000e+11
# 2021-01-09  40788.64  41436.35  38980.88  6.198416e+10  7.490000e+11
# 2021-01-10  40254.22  41420.19  35984.63  7.998075e+10  7.130000e+11
# 2021-01-11  38346.53  38346.53  30549.60  1.233210e+11  6.614570e+11
#
#             TOMORROW_CLOSE
# Date
# 2021-01-07        40797.61
# 2021-01-08        40254.55
# 2021-01-09        38356.44
# 2021-01-10        35566.66
# 2021-01-11        33922.96

# %% [markdown]
# ## At this point, the data is ready for the next step: Splitting it to Train and Test parts. ( during training, Keras will take care of the validation split)

# %%
# Split train data (90%) and test data (10%)
train_size = int(len(df)*0.9)
#train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]

# %%
# Split train data to X and y
X_train = train_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_train = train_dataset.loc[:,['TOMORROW_CLOSE']]
# Split test data to X and y
X_test = test_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_test = test_dataset.loc[:,['TOMORROW_CLOSE']]

# %%
#Plot train and test data
plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset.TOMORROW_CLOSE)
plt.plot(test_dataset.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (2533, 6)
# Dimension of test data:  (282, 6)

# %% [markdown]
# ### Note that the data is between 2013 and 2017 contains nothing to learn. Therefore, change the split of the data, and start from 2017.

# %%
# Split train data (90%) and test data (10%)
train_size1 = int(len(df)*0.9)
train_dataset1, test_dataset1 = df.iloc[1300:train_size1],df.iloc[train_size1:] # 1300 days to reach 2014 from the useless 2013.

# %%
# Split train data to X and y
X_train1 = train_dataset1.drop('TOMORROW_CLOSE', axis = 1)
y_train1 = train_dataset1.loc[:,['TOMORROW_CLOSE']]
# Split test data to X and y
X_test1 = test_dataset1.drop('TOMORROW_CLOSE', axis = 1)
y_test1 = test_dataset1.loc[:,['TOMORROW_CLOSE']]

# %%
#Plot train and test data
plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset1.TOMORROW_CLOSE)
plt.plot(test_dataset1.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set','Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset1.shape)
print('Dimension of test data: ', test_dataset1.shape)
# Out:
# Dimension of train data:  (1233, 6)
# Dimension of test data:  (282, 6)

# %% [markdown]
# **Normalize the Data using MinMaxScalar**

# %%
# Different scaler for input and output ----> Normalizate the data
scaler_x = MinMaxScaler(feature_range = (-1,1))
scaler_y = MinMaxScaler(feature_range = (-1,1))

# Fit the scaler using available training data
input_scaler1 = scaler_x.fit(X_train1)
output_scaler1 = scaler_y.fit(y_train1)

# Apply the scaler to training data
train_y_norm1 = output_scaler1.transform(y_train1)
train_x_norm1 = input_scaler1.transform(X_train1)

# Apply the scaler to test data
test_y_norm1 = output_scaler1.transform(y_test1)
test_x_norm1 = input_scaler1.transform(X_test1)

# %% [markdown]
# # Next, prepare the data to be fed to different RNN models, by shaping it into a 3-D tensor

# %%
# Create 3 dimensional data set 
def threeD_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
        
    return np.array(Xs), np.array(ys)


TIME_STEPS = 20 # number of days to take a look at to perform predictions, can be in the past of future in case of bidrectional models.


X_test1, y_test1 = threeD_dataset(test_x_norm1, test_y_norm1, TIME_STEPS)
X_train1, y_train1 = threeD_dataset(train_x_norm1, train_y_norm1, TIME_STEPS)

print('X_train1.shape: ', X_train1.shape)
print('y_train1.shape: ', y_train1.shape)
print('X_test1.shape: ', X_test1.shape) 
print('y_test1.shape: ', y_test1.shape)
# Out:
# X_train1.shape:  (1213, 20, 5)
# y_train1.shape:  (1213, 1)
# X_test1.shape:  (262, 20, 5)
# y_test1.shape:  (262, 1)

# %%
X_train1.shape[1]
# Out:
# 20

# %% [markdown]
# ### Finally, we can build our sixth  model, which is 1D_CONV_Bi_GRU with one hidden layer, a dropout later, and a dense layer at the end.
# ### This is a simple model that we will developed and enhanced by time

# %%
def create_model_1d_conv_bilstm():
    model = Sequential()

    # Conv Layer
    model.add(Conv1D(64, 1, activation='relu',input_shape = X_train1.shape[1:]))

    # First layer of BiLSTM
    model.add(Bidirectional(LSTM(units = 128, return_sequences=False), input_shape=[X_train.shape[1],1]))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam') # use Adam with default parameters, learning rate, ...
    return model

# %%
model_1d_conv_bi_lstm = create_model_1d_conv_bilstm()

# %%
# Let's check the summary of our baby model
model_1d_conv_bi_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 64)            384
#
#  bidirectional (Bidirectiona  (None, 256)              197632
#  l)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fit the MODEL !

# %%
## Fit the model !
early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 40) # use early stop technique to stop the training process if the val loss didn't improve for 10 epochs

# decaying lr on every 2nd epoch by 5%
def scheduler(epoch, lr):
    rate = 1 - 0.05
    if epoch%2 == 0:
        return lr*rate
    return lr

LRscheduler = LearningRateScheduler(scheduler)
callbacks_list = [early_stop, LRscheduler]
history_conv_bi_lstm = model_1d_conv_bi_lstm.fit(X_train1, y_train1, epochs = 100, validation_split=0.2,batch_size = 64, shuffle = False, callbacks = callbacks_list) # no shuffle, as it is time series data, order matters, use 100 epochs
# Out:
# Epoch 1/100
# 16/16 [==============================] - 13s 117ms/step - loss: 0.1682 - val_loss: 0.0262 - lr: 9.5000e-04
# Epoch 2/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0328 - val_loss: 0.0102 - lr: 9.5000e-04
# Epoch 3/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0291 - val_loss: 0.0140 - lr: 9.0250e-04
# Epoch 4/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0221 - val_loss: 0.0104 - lr: 9.0250e-04
# Epoch 5/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0153 - val_loss: 0.0128 - lr: 8.5737e-04
# Epoch 6/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0100 - lr: 8.5737e-04
# Epoch 57/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0077 - lr: 2.2594e-04
# Epoch 58/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0078 - lr: 2.2594e-04
# Epoch 59/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0078 - lr: 2.1464e-04
# Epoch 60/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.0077 - lr: 2.1464e-04
# Epoch 61/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0079 - lr: 2.0391e-04
# Epoch 62/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0081 - lr: 2.0391e-04
# Epoch 63/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0081 - lr: 1.9371e-04
# Epoch 64/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 0.0081 - lr: 1.9371e-04
# Epoch 65/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0082 - lr: 1.8403e-04
# Epoch 66/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0084 - lr: 1.8403e-04
# Epoch 67/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0085 - lr: 1.7482e-04
# Epoch 68/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0084 - lr: 1.7482e-04

# %%
#Plot train and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.rcParams['figure.dpi'] = 360
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    
plot_loss (history_conv_bi_lstm, 'LSTM')

# %%
# Reverse the normalization back
y_test1 = scaler_y.inverse_transform(y_test1)
y_train1 = scaler_y.inverse_transform(y_train1)

# %%
# Validate
def prediction(model):
    prediction = model.predict(X_test1)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction
  
prediction_conv_bi_LSTM = prediction(model_1d_conv_bi_lstm)

# %%
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(10, 6))
    plt.rcParams['figure.dpi'] = 360
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test1), label='True Future')
    plt.plot(np.arange(range_future), np.array(prediction),label='Prediction')

    plt.title('True future vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Date')
    plt.ylabel('Close value (USD $)')

plot_future(prediction_conv_bi_LSTM, 'Conv-Bi-GRU', y_test1)

# %%
# Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()

    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

evaluate_prediction(prediction_conv_bi_LSTM, y_test1, 'conv_bi_LSTM')
# Out:
# conv_bi_LSTM:
# Mean Absolute Error: 2851.5205
# Root Mean Square Error: 4883.6733
