# %% [markdown]
# This short notebook aims at extracting 546 raw tweets regarding bitcoin between 2021-01-01 & 2022-07-01, save them in df and download them in .csv file

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
quarey  = "(from:TheEconomist OR from:CryptoA40672341 OR from:cz_binance) lang:en until:2022-07-01 since:2021-01-01"

# %%
tweets = [] # empty list to store the tweets

# %%
limit = 546 # get 546 tweets equal to the number rows or days we had for historical data

# %%
for tweet in sntwitter.TwitterSearchScraper(quarey).get_items():
  
  if len(tweets) == limit:
    break
  else:
    tweets.append([tweet.date,tweet.content])

df = pd.DataFrame(tweets,columns = ['Date','tweet'])

# %%
print(df)
# Out:
#                          Date  \
# 0   2022-06-30 23:39:06+00:00
# 1   2022-06-30 23:38:05+00:00
# 2   2022-06-30 23:31:05+00:00
# 3   2022-06-30 23:24:53+00:00
# 4   2022-06-30 23:21:50+00:00
# ..                        ...
# 541 2022-06-26 12:17:03+00:00
# 542 2022-06-26 12:08:18+00:00
# 543 2022-06-26 11:50:04+00:00
# 544 2022-06-26 11:47:54+00:00
# 545 2022-06-26 11:32:21+00:00
#
#                                                  tweet
# 0    For a long time, America was “the undisputed l...
# 1    Breathtaking change marked the Supreme Court t...
# 2    Mars strikes the right balance between making ...
# 3    @goodmazino @CryptoNCoffeee It's a banking iss...
# 4    Web3 companies don't need to sell data.\n\nSim...
# ..                                                 ...
# 541  The conservative People’s Party’s victory in A...
# 542  Food vendors are not a nuisance, argues our fo...
# 543  The Supreme Court has never before withdrawn a...
# ...

# %%
import base64
import pandas as pd
from IPython.display import HTML

# %%
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(df)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
