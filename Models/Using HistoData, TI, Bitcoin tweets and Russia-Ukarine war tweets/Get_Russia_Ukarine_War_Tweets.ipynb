# %% [markdown]
# This short notebook aims at extracting 546 raw tweets regarding Russia-Ukarine War between 2021-01-01 & 2022-07-01, save them in df and download them in .csv file

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
quarey  = "(russia OR ukraine OR war OR conflict) min_replies:280 min_faves:280 min_retweets:280 lang:en until:2022-07-01 since:2021-01-01"

# %%
tweets = [] # empty list to store the tweets

# %%
limit = 546 # get 546 tweets equal to the number rows or days we had for historical data

# %%
for tweet in sntwitter.TwitterSearchScraper(quarey).get_items():
  
  if len(tweets) == limit:
    break
  else:
    tweets.append([tweet.date,tweet.content])

df = pd.DataFrame(tweets,columns = ['Date','tweet'])

# %%
print(df)
# Out:
#                          Date  \
# 0   2022-06-30 20:36:30+00:00
# 1   2022-06-30 19:24:56+00:00
# 2   2022-06-30 18:24:05+00:00
# 3   2022-06-30 18:17:04+00:00
# 4   2022-06-30 18:00:02+00:00
# ..                        ...
# 541 2022-05-20 19:25:19+00:00
# 542 2022-05-20 18:39:14+00:00
# 543 2022-05-20 18:36:26+00:00
# 544 2022-05-20 18:17:18+00:00
# 545 2022-05-20 17:04:34+00:00
#
#                                                  tweet
# 0    So apparently the Donald is headed soon to Anc...
# 1    BIDEN: "The reason why gas prices are up, is b...
# 2    Ukraine is the MIC’s new Iraq wrapped up with ...
# 3    REPORTER: "How long is it fair to expect Ameri...
# 4    Strengthening security. \n\nDefending democrac...
# ..                                                 ...
# 541  @truth_tesla @veespike @HillaryClinton @Twitte...
# 542  LOCK HER UP: Hillary Clinton Personally Approv...
# 543  @Jim_Jordan All true. \n\nBet most people stil...
# ...

# %%
import base64
import pandas as pd
from IPython.display import HTML

# %%
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(df)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
