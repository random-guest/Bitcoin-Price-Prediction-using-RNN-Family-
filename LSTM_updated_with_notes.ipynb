# %% [markdown]
# **This model will utilize the LSTM netwrok only to predicts next day closing price of the bitcoin.**

# %% [markdown]
# The next piece of code will **import the neccassary libraries** that will be used throughout the code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
sns.set_style("white")
import scipy 
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from IPython.core.pylabtools import figsize
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from keras.layers import *
from keras.models import *
from keras import backend as K

# Set random seed for reproducibility
tf.random.set_seed(42)

# %% [markdown]
# Now that we have the imported the required libraries, we need to get the data.
# We will do so by first **installing the historic crypto data api**, that will allow us to get the data of any crypto (mainly the famous ones), on any range we wish, for example, we can get the bitcoin data from a chosen date to a chosen date, per 60 seconds up to per 24 hrs.

# %%
# !pip install Historic-Crypto
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Historic-Crypto in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Historic-Crypto) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->Historic-Crypto) (1.24.3)

# %%
import warnings
warnings.filterwarnings("ignore")

# From the histroic cyrpto import the historical data
from Historic_Crypto import HistoricalData

# %% [markdown]
# Next step would be to **get the data** . The chosen data will be reterived chunk wise. Here, we will specify the name of the cryptocurrency we are interested in, for instance in our case 'BTC-USD' is the bitcoin one, then we should specify number of seconds that will seperate the data. For example, 86400 is the number of seconds in 1 day. So, we will reterive the data on a daily bases. Next, we will specify the starting date in the form of year-month-day-hour-minute and finally the ending date, in the same format.
#
# **In our case, we will reterive data between 01/01/2021 and 31/05/2022 on daily bases.**

# %%
btc_historicals = HistoricalData('BTC-USD',86400,'2021-01-01-00-00', '2022-05-31-00-00').retrieve_data() # cyrpto name, number of seconds, start date, end date
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-01-01T00:00:00
# Provisional End: 2021-10-28T00:00:00
# Data for chunk 1 of 2 extracted
# Provisional Start: 2021-10-28T00:00:00
# Provisional End: 2022-08-24T00:00:00
# Data for chunk 2 of 2 extracted

# %% [markdown]
# In the next few lines, we will try to have **a closer look at the data** and check whether it needs any cleaning or not.

# %%
# check the shape of the data
btc_historicals.shape
# Out:
# (515, 5)

# %%
# few the last 5 rows of the data
btc_historicals.tail()
# Out:
#                  low      high      open     close        volume
# time
# 2022-05-27  28220.00  29355.40  29166.06  28598.31  21035.537369
# 2022-05-28  28500.00  29239.52  28598.31  29008.99   7717.343676
# 2022-05-29  28809.84  29550.00  29008.99  29447.07   6727.927704
# 2022-05-30  29273.65  32232.16  29447.08  31711.42  24915.372760
# 2022-05-31  31195.90  32383.96  31716.67  31784.05  21187.776674

# %% [markdown]
# As we can observe, the data is in the form of low high open close volume, that means, on te given date, the lowest price was low, the higest price was high, the openning price was open, the closing price was close, and the volume of data that was exchanges was volume.

# %%
# Check out variables
btc_historicals.dtypes
# Out:
# low       float64
# high      float64
# open      float64
# close     float64
# volume    float64
# dtype: object

# %%
# assign a dummy variable to hold the data, so that incase we need to do any
# modifications, we wouldn't lose the orginal data.
tst = btc_historicals

# %%
# The data is clean already, but let us try to check for any null or NA vales.
print('Null Values:',tst.isnull().values.sum())
print('If any NA values:', tst.isnull().values.any())
# Out:
# Null Values: 0
# If any NA values: False

# %% [markdown]
# Next, we will need to do some modifications to the data we have. The first one will be to create a new variable called, Tomorrrow_Close which shifts the close price by 1 row and thus the last row will be deleted. This is done to add a new important feature so that our model will learn from.

# %%
# Create variable '‘TOMORROW_CLOSE’' which shifts 'Close' up by 1
tst['TOMORROW_CLOSE'] = tst['close'].shift(-1,fill_value=0)

# %%
# drop last row because we shifted value (remember this when you add your forecasting data)
tst.drop(tst.tail(1).index,inplace=True)

# %%
# Drop close column, since we created new ‘TOMORROW_CLOSE’
tst = tst.drop(columns=['close'])

# %%
tst.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
# check the shape of data to know how many sample we have
tst.shape
# Out:
# (514, 5)

# %%
# Split the data intro train data (90%) and test data (10%)

train_size = int(len(tst)*0.90)
train_dataset, test_dataset = tst.iloc[:train_size],tst.iloc[train_size:]

# %%
# Double check the split
train_dataset.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521        33080.66
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506        32019.99
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685        34030.64
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200        36859.26
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200        39505.56

# %%
# Double check the split
test_dataset.head()
# Out:
#                  low      high      open        volume  TOMORROW_CLOSE
# time
# 2022-04-09  42118.96  42816.38  42261.90   4805.716898        42165.96
# 2022-04-10  41885.86  43443.32  42766.46   5770.493681        39535.87
# 2022-04-11  39204.59  42424.14  42165.96  17229.372901        40086.23
# 2022-04-12  39250.00  40705.68  39535.88  13866.418474        41146.68
# 2022-04-13  39550.00  41570.88  40086.70  11457.633805        39954.08

# %%
# Split train data to X and y
X_train = train_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_train = train_dataset.loc[:,['TOMORROW_CLOSE']]

# Split test data to X and y
X_test = test_dataset.drop('TOMORROW_CLOSE', axis = 1)
y_test = test_dataset.loc[:,['TOMORROW_CLOSE']]

# %%
# Double check the X
X_train.head()
# Out:
#                  low      high      open        volume
# time
# 2021-01-02  29039.00  33300.00  29413.29  46675.246521
# 2021-01-03  32008.62  34810.00  32222.88  36951.716506
# 2021-01-04  27678.00  33666.99  33082.84  46045.389685
# 2021-01-05  29891.13  34499.67  32020.22  42282.569200
# 2021-01-06  33352.54  37000.00  34043.91  45744.103200

# %%
#Plot train and test data
plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset.TOMORROW_CLOSE)
plt.plot(test_dataset.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (462, 5)
# Dimension of test data:  (52, 5)

# %% [markdown]
# As we can observe, we have chosen the starting date to be 01/01/2021 because of the dynamic change in the price has started around this date, and so if the model will be able to predict the daynamic behaviour later, it has to be trained on similiar behaviour data. While, the data before this date is relatively steady, and didn't help the model the learn anything from. Matter fact, it lead to poor results.
# Below, is a plot of the bitcoin price evolution from 2012.

# %%
btc = HistoricalData('BTC-USD',86400,'2012-01-01-00-00', '2022-05-31-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2012-01-01T00:00:00
# Provisional End: 2012-10-27T00:00:00
# Data for chunk 1 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2012-01-01T00:00:00'
# Provisional Start: 2012-10-27T00:00:00
# Provisional End: 2013-08-23T00:00:00
# Data for chunk 2 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2012-10-27T00:00:00'
# Provisional Start: 2013-08-23T00:00:00
# Provisional End: 2014-06-19T00:00:00
# Data for chunk 3 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2013-08-23T00:00:00'
# Provisional Start: 2014-06-19T00:00:00
# Provisional End: 2015-04-15T00:00:00
# Data for chunk 4 of 13 extracted
# CoinBase Pro API did not have available data for 'BTC-USD' beginning at 2012-01-01-00-00.
#                         Trying a later date:'2014-06-19T00:00:00'
# Provisional Start: 2015-04-15T00:00:00
# Provisional End: 2016-02-09T00:00:00
# Data for chunk 5 of 13 extracted
# Provisional Start: 2016-02-09T00:00:00
# Provisional End: 2016-12-05T00:00:00
# Data for chunk 6 of 13 extracted
# Provisional Start: 2016-12-05T00:00:00
# Provisional End: 2017-10-01T00:00:00
# Data for chunk 7 of 13 extracted
# Provisional Start: 2017-10-01T00:00:00
# Provisional End: 2018-07-28T00:00:00
# Data for chunk 8 of 13 extracted
# Provisional Start: 2018-07-28T00:00:00
# Provisional End: 2019-05-24T00:00:00
# Data for chunk 9 of 13 extracted
# Provisional Start: 2019-05-24T00:00:00
# Provisional End: 2020-03-19T00:00:00
# Data for chunk 10 of 13 extracted
# Provisional Start: 2020-03-19T00:00:00
# Provisional End: 2021-01-13T00:00:00
# Data for chunk 11 of 13 extracted
# Provisional Start: 2021-01-13T00:00:00
# Provisional End: 2021-11-09T00:00:00
# Data for chunk 12 of 13 extracted
# Provisional Start: 2021-11-09T00:00:00
# Provisional End: 2022-09-05T00:00:00
# Data for chunk 13 of 13 extracted

# %%
# Create variable '‘TOMORROW_CLOSE’' which shifts 'Close' up by 1
btc['TOMORROW_CLOSE'] = btc['close'].shift(-1,fill_value=0)

# drop last row because we shifted value (remember this when you add your forecasting data)
btc.drop(btc.tail(1).index,inplace=True) 

# Drop close column, since we created new ‘TOMORROW_CLOSE’
btc = btc.drop(columns=['close'])

# Split the data intro train data (90%) and test data (10%)

train_size_1 = int(len(btc)*0.90)
train_dataset_1, test_dataset_1 = btc.iloc[:train_size_1],btc.iloc[train_size_1:]

# Split train data to X and y
X_train_1 = train_dataset_1.drop('TOMORROW_CLOSE', axis = 1)
y_train_1 = train_dataset_1.loc[:,['TOMORROW_CLOSE']]

# Split test data to X and y
X_test_1 = test_dataset_1.drop('TOMORROW_CLOSE', axis = 1)
y_test_1 = test_dataset_1.loc[:,['TOMORROW_CLOSE']]

#Plot train and test data
plt.figure(figsize = (12, 6))
plt.rcParams['figure.dpi'] = 360
plt.plot(train_dataset_1.TOMORROW_CLOSE)
plt.plot(test_dataset_1.TOMORROW_CLOSE)
plt.xlabel('Date')
plt.ylabel('Close value (US$)')
plt.legend(['Train set', 'Test set'], loc='upper left')
print('Dimension of train data: ',train_dataset_1.shape)
print('Dimension of test data: ', test_dataset_1.shape)
# Out:
# Dimension of train data:  (2256, 5)
# Dimension of test data:  (251, 5)

# %% [markdown]
# **Data Normalization**

# %%
# Different scaler for input and output ----> Normalizate the data
scaler_x = MinMaxScaler(feature_range = (-1,1))
scaler_y = MinMaxScaler(feature_range = (-1,1))

# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)

# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# %% [markdown]
# **Prepare the data to be fed into the model.
# Create 3 D tensor of data.**

# %%
# Create 3 dimensional data set 
def threeD_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
        
    return np.array(Xs), np.array(ys)


TIME_STEPS = 15 # which means the model will make predictions of ‘TOMORROW_CLOSE’ based on the input from the 10 previous days or future days bi-lstm or bi-gru

X_test, y_test = threeD_dataset(test_x_norm, test_y_norm, TIME_STEPS)
X_train, y_train = threeD_dataset(train_x_norm, train_y_norm, TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (447, 15, 4)
# y_train.shape:  (447, 1)
# X_test.shape:  (37, 15, 4)
# y_test.shape:  (37, 1)

# %% [markdown]
# **FINALLY, we can CONSTUCT the MODEL**

# %%
# Create LSTM 
def create_model(m):
    model = Sequential()
    # First layer of LSTM
    model.add(m (units = 64, activation = 'relu', return_sequences = False, input_shape = [X_train.shape[1], X_train.shape[2]])) # use 64 hidden units, relu acitvation function,
    # return_sequence is False, because we will use one layer LSTM
    # Add a dense layer
    model.add(Dense(units = 1))  # number of units is 1, because we will predict one output, which is tomorrow's price and compare it with the ground truth  
    model.compile(loss = 'mse', optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001 ) ) # use loss as MSE and Adam optimizer, with learning rate 0.00001
    return model

# %%
# Create the model by passing LSTM to the model.
model_lstm = create_model(LSTM)

# %%
# Let's check the summary of our baby model
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                17664
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 17,729
# Trainable params: 17,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
# start the  training process, with 800 epochs, (the number of times the model will look at the entire dataset), validation split is 20 % from the training data, this is
# done autmatically by Keras, batch size of 8, meaning that, the model will take try to minimize the loss by looking at only 8 samples, shuffle is false, because this is time 
# data, so the order matters alot.
history_lstm = model_lstm.fit(X_train, y_train, epochs = 800, validation_split = 0.2,batch_size = 8, shuffle = False)
# Out:
# Epoch 1/800
# 45/45 [==============================] - 3s 22ms/step - loss: 0.2717 - val_loss: 0.1632
# Epoch 2/800
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2667 - val_loss: 0.1605
# Epoch 3/800
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2619 - val_loss: 0.1578
# Epoch 4/800
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2571 - val_loss: 0.1550
# Epoch 5/800
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2523 - val_loss: 0.1523
# Epoch 6/800
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2476 - val_loss: 0.1496
# Epoch 7/800
# 45/45 [==============================] - 1s 14ms/step - loss: 0.2430 - val_loss: 0.1469
# Epoch 8/800
# 45/45 [==============================] - 1s 13ms/step - loss: 0.2384 - val_loss: 0.1442
# Epoch 9/800
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2338 - val_loss: 0.1415
# Epoch 10/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2293 - val_loss: 0.1389
# Epoch 11/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2247 - val_loss: 0.1362
# Epoch 12/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2203 - val_loss: 0.1336
# Epoch 13/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2158 - val_loss: 0.1310
# Epoch 14/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2114 - val_loss: 0.1284
# Epoch 15/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2069 - val_loss: 0.1258
# Epoch 16/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2025 - val_loss: 0.1232
# Epoch 17/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1980 - val_loss: 0.1205
# Epoch 18/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1936 - val_loss: 0.1179
# Epoch 19/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1892 - val_loss: 0.1153
# Epoch 20/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1847 - val_loss: 0.1127
# Epoch 21/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1803 - val_loss: 0.1101
# Epoch 22/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1758 - val_loss: 0.1075
# Epoch 23/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1714 - val_loss: 0.1049
# Epoch 24/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1670 - val_loss: 0.1022
# Epoch 25/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1625 - val_loss: 0.0996
# Epoch 26/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1580 - val_loss: 0.0969
# Epoch 27/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1534 - val_loss: 0.0941
# Epoch 28/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1488 - val_loss: 0.0914
# Epoch 29/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1442 - val_loss: 0.0886
# Epoch 30/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1397 - val_loss: 0.0858
# Epoch 31/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1352 - val_loss: 0.0830
# Epoch 32/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.1307 - val_loss: 0.0802
# Epoch 33/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1263 - val_loss: 0.0774
# Epoch 34/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1219 - val_loss: 0.0746
# Epoch 35/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1175 - val_loss: 0.0718
# Epoch 36/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1131 - val_loss: 0.0691
# Epoch 37/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1088 - val_loss: 0.0663
# Epoch 38/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1046 - val_loss: 0.0636
# Epoch 39/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1004 - val_loss: 0.0609
# Epoch 40/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0963 - val_loss: 0.0582
# Epoch 41/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0924 - val_loss: 0.0557
# Epoch 42/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0886 - val_loss: 0.0532
# Epoch 43/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0849 - val_loss: 0.0508
# Epoch 44/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0814 - val_loss: 0.0485
# Epoch 45/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0781 - val_loss: 0.0464
# Epoch 46/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0749 - val_loss: 0.0444
# Epoch 47/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0720 - val_loss: 0.0425
# Epoch 48/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0693 - val_loss: 0.0409
# Epoch 49/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0668 - val_loss: 0.0393
# Epoch 50/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0645 - val_loss: 0.0380
# Epoch 51/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0624 - val_loss: 0.0367
# Epoch 52/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0605 - val_loss: 0.0357
# Epoch 53/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0588 - val_loss: 0.0347
# Epoch 54/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0572 - val_loss: 0.0339
# Epoch 55/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0558 - val_loss: 0.0332
# Epoch 56/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0545 - val_loss: 0.0326
# Epoch 57/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0533 - val_loss: 0.0320
# Epoch 58/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0522 - val_loss: 0.0316
# Epoch 59/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0512 - val_loss: 0.0312
# Epoch 60/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0503 - val_loss: 0.0308
# Epoch 61/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0495 - val_loss: 0.0305
# Epoch 62/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0487 - val_loss: 0.0303
# Epoch 63/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0481 - val_loss: 0.0300
# Epoch 64/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0474 - val_loss: 0.0298
# Epoch 65/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0469 - val_loss: 0.0296
# Epoch 66/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0463 - val_loss: 0.0295
# Epoch 67/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0459 - val_loss: 0.0293
# Epoch 68/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0454 - val_loss: 0.0292
# Epoch 69/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0450 - val_loss: 0.0290
# Epoch 70/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0447 - val_loss: 0.0289
# Epoch 71/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0443 - val_loss: 0.0288
# Epoch 72/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0440 - val_loss: 0.0287
# Epoch 73/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0437 - val_loss: 0.0286
# Epoch 74/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0435 - val_loss: 0.0284
# Epoch 75/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0432 - val_loss: 0.0283
# Epoch 76/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0430 - val_loss: 0.0282
# Epoch 77/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0428 - val_loss: 0.0281
# Epoch 78/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0426 - val_loss: 0.0280
# Epoch 79/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0424 - val_loss: 0.0279
# Epoch 80/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0422 - val_loss: 0.0278
# Epoch 81/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0420 - val_loss: 0.0277
# Epoch 82/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0419 - val_loss: 0.0275
# Epoch 83/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0417 - val_loss: 0.0274
# Epoch 84/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0416 - val_loss: 0.0273
# Epoch 85/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0272
# Epoch 86/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0413 - val_loss: 0.0271
# Epoch 87/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0270
# Epoch 88/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0411 - val_loss: 0.0269
# Epoch 89/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0410 - val_loss: 0.0268
# Epoch 90/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0408 - val_loss: 0.0267
# Epoch 91/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0407 - val_loss: 0.0266
# Epoch 92/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0406 - val_loss: 0.0265
# Epoch 93/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0405 - val_loss: 0.0264
# Epoch 94/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0404 - val_loss: 0.0263
# Epoch 95/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0403 - val_loss: 0.0262
# Epoch 96/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0402 - val_loss: 0.0261
# Epoch 97/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0401 - val_loss: 0.0260
# Epoch 98/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0400 - val_loss: 0.0259
# Epoch 99/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0399 - val_loss: 0.0259
# Epoch 100/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0398 - val_loss: 0.0258
# Epoch 101/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0397 - val_loss: 0.0257
# Epoch 102/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0396 - val_loss: 0.0256
# Epoch 103/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0395 - val_loss: 0.0255
# Epoch 104/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0395 - val_loss: 0.0254
# Epoch 105/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0253
# Epoch 106/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0253
# Epoch 107/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0392 - val_loss: 0.0252
# Epoch 108/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.0251
# Epoch 109/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0390 - val_loss: 0.0250
# Epoch 110/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0389 - val_loss: 0.0250
# Epoch 111/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0389 - val_loss: 0.0249
# Epoch 112/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0388 - val_loss: 0.0248
# Epoch 113/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0387 - val_loss: 0.0248
# Epoch 114/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0386 - val_loss: 0.0247
# Epoch 115/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0385 - val_loss: 0.0246
# Epoch 116/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0384 - val_loss: 0.0246
# Epoch 117/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0383 - val_loss: 0.0245
# Epoch 118/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0383 - val_loss: 0.0244
# Epoch 119/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0382 - val_loss: 0.0244
# Epoch 120/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0381 - val_loss: 0.0243
# Epoch 121/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0380 - val_loss: 0.0242
# Epoch 122/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0379 - val_loss: 0.0242
# Epoch 123/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0378 - val_loss: 0.0241
# Epoch 124/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0378 - val_loss: 0.0241
# Epoch 125/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0377 - val_loss: 0.0240
# Epoch 126/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0376 - val_loss: 0.0239
# Epoch 127/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0375 - val_loss: 0.0239
# Epoch 128/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0374 - val_loss: 0.0238
# Epoch 129/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0373 - val_loss: 0.0238
# Epoch 130/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0372 - val_loss: 0.0237
# Epoch 131/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0371 - val_loss: 0.0237
# Epoch 132/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0371 - val_loss: 0.0236
# Epoch 133/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0370 - val_loss: 0.0236
# Epoch 134/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0369 - val_loss: 0.0235
# Epoch 135/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0368 - val_loss: 0.0234
# Epoch 136/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0367 - val_loss: 0.0234
# Epoch 137/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0366 - val_loss: 0.0233
# Epoch 138/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0365 - val_loss: 0.0233
# Epoch 139/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0364 - val_loss: 0.0232
# Epoch 140/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0363 - val_loss: 0.0232
# Epoch 141/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0362 - val_loss: 0.0232
# Epoch 142/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0361 - val_loss: 0.0231
# Epoch 143/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0360 - val_loss: 0.0231
# Epoch 144/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0360 - val_loss: 0.0230
# Epoch 145/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0359 - val_loss: 0.0230
# Epoch 146/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0358 - val_loss: 0.0229
# Epoch 147/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0357 - val_loss: 0.0229
# Epoch 148/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0356 - val_loss: 0.0229
# Epoch 149/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0355 - val_loss: 0.0228
# Epoch 150/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0354 - val_loss: 0.0228
# Epoch 151/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0353 - val_loss: 0.0227
# Epoch 152/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0352 - val_loss: 0.0227
# Epoch 153/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0351 - val_loss: 0.0227
# Epoch 154/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0350 - val_loss: 0.0226
# Epoch 155/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0349 - val_loss: 0.0226
# Epoch 156/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0348 - val_loss: 0.0225
# Epoch 157/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0347 - val_loss: 0.0225
# Epoch 158/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0346 - val_loss: 0.0225
# Epoch 159/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0345 - val_loss: 0.0224
# Epoch 160/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0344 - val_loss: 0.0224
# Epoch 161/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0344 - val_loss: 0.0224
# Epoch 162/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0343 - val_loss: 0.0224
# Epoch 163/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0342 - val_loss: 0.0223
# Epoch 164/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0341 - val_loss: 0.0223
# Epoch 165/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0340 - val_loss: 0.0223
# Epoch 166/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0339 - val_loss: 0.0223
# Epoch 167/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0339 - val_loss: 0.0222
# Epoch 168/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0338 - val_loss: 0.0222
# Epoch 169/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0337 - val_loss: 0.0222
# Epoch 170/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0336 - val_loss: 0.0222
# Epoch 171/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0336 - val_loss: 0.0221
# Epoch 172/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0335 - val_loss: 0.0221
# Epoch 173/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0334 - val_loss: 0.0221
# Epoch 174/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0333 - val_loss: 0.0221
# Epoch 175/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0333 - val_loss: 0.0221
# Epoch 176/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0332 - val_loss: 0.0220
# Epoch 177/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0331 - val_loss: 0.0220
# Epoch 178/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0331 - val_loss: 0.0220
# Epoch 179/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0330 - val_loss: 0.0220
# Epoch 180/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0329 - val_loss: 0.0220
# Epoch 181/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0329 - val_loss: 0.0219
# Epoch 182/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0328 - val_loss: 0.0219
# Epoch 183/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0328 - val_loss: 0.0219
# Epoch 184/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0327 - val_loss: 0.0219
# Epoch 185/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0326 - val_loss: 0.0219
# Epoch 186/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0326 - val_loss: 0.0219
# Epoch 187/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0325 - val_loss: 0.0218
# Epoch 188/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0325 - val_loss: 0.0218
# Epoch 189/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0324 - val_loss: 0.0218
# Epoch 190/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0324 - val_loss: 0.0218
# Epoch 191/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0323 - val_loss: 0.0218
# Epoch 192/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0322 - val_loss: 0.0217
# Epoch 193/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0322 - val_loss: 0.0217
# Epoch 194/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0321 - val_loss: 0.0217
# Epoch 195/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0321 - val_loss: 0.0217
# Epoch 196/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0320 - val_loss: 0.0217
# Epoch 197/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0320 - val_loss: 0.0217
# Epoch 198/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0319 - val_loss: 0.0216
# Epoch 199/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0319 - val_loss: 0.0216
# Epoch 200/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0318 - val_loss: 0.0216
# Epoch 201/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0318 - val_loss: 0.0216
# Epoch 202/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0216
# Epoch 203/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0317 - val_loss: 0.0215
# Epoch 204/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0316 - val_loss: 0.0215
# Epoch 205/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0316 - val_loss: 0.0215
# Epoch 206/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0315 - val_loss: 0.0215
# Epoch 207/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0315 - val_loss: 0.0215
# Epoch 208/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0215
# Epoch 209/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0215
# Epoch 210/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0313 - val_loss: 0.0214
# Epoch 211/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0313 - val_loss: 0.0214
# Epoch 212/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0214
# Epoch 213/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0214
# Epoch 214/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0312 - val_loss: 0.0214
# Epoch 215/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0311 - val_loss: 0.0214
# Epoch 216/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0311 - val_loss: 0.0213
# Epoch 217/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0310 - val_loss: 0.0213
# Epoch 218/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0310 - val_loss: 0.0213
# Epoch 219/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0310 - val_loss: 0.0213
# Epoch 220/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0309 - val_loss: 0.0213
# Epoch 221/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0309 - val_loss: 0.0213
# Epoch 222/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0308 - val_loss: 0.0213
# Epoch 223/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0308 - val_loss: 0.0212
# Epoch 224/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0308 - val_loss: 0.0212
# Epoch 225/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0307 - val_loss: 0.0212
# Epoch 226/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0307 - val_loss: 0.0212
# Epoch 227/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0306 - val_loss: 0.0212
# Epoch 228/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0306 - val_loss: 0.0212
# Epoch 229/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0306 - val_loss: 0.0212
# Epoch 230/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0305 - val_loss: 0.0212
# Epoch 231/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0305 - val_loss: 0.0211
# Epoch 232/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0305 - val_loss: 0.0211
# Epoch 233/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0304 - val_loss: 0.0211
# Epoch 234/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0304 - val_loss: 0.0211
# Epoch 235/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0304 - val_loss: 0.0211
# Epoch 236/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0303 - val_loss: 0.0211
# Epoch 237/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0303 - val_loss: 0.0211
# Epoch 238/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0303 - val_loss: 0.0211
# Epoch 239/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0302 - val_loss: 0.0210
# Epoch 240/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0302 - val_loss: 0.0210
# Epoch 241/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0302 - val_loss: 0.0210
# Epoch 242/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0301 - val_loss: 0.0210
# Epoch 243/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0301 - val_loss: 0.0210
# Epoch 244/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0301 - val_loss: 0.0210
# Epoch 245/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0300 - val_loss: 0.0210
# Epoch 246/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0300 - val_loss: 0.0209
# Epoch 247/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0300 - val_loss: 0.0209
# Epoch 248/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0299 - val_loss: 0.0209
# Epoch 249/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0299 - val_loss: 0.0209
# Epoch 250/800
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0299 - val_loss: 0.0209
# Epoch 251/800
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0298 - val_loss: 0.0209
# Epoch 252/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0298 - val_loss: 0.0209
# Epoch 253/800
# 45/45 [==============================] - 1s 18ms/step - loss: 0.0298 - val_loss: 0.0209
# Epoch 254/800
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0297 - val_loss: 0.0208
# Epoch 255/800
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0297 - val_loss: 0.0208
# Epoch 256/800
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0297 - val_loss: 0.0208
# Epoch 257/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0297 - val_loss: 0.0208
# Epoch 258/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0296 - val_loss: 0.0208
# Epoch 259/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0296 - val_loss: 0.0208
# Epoch 260/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0296 - val_loss: 0.0208
# Epoch 261/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0295 - val_loss: 0.0208
# Epoch 262/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0295 - val_loss: 0.0207
# Epoch 263/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0295 - val_loss: 0.0207
# Epoch 264/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0295 - val_loss: 0.0207
# Epoch 265/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0294 - val_loss: 0.0207
# Epoch 266/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0294 - val_loss: 0.0207
# Epoch 267/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0294 - val_loss: 0.0207
# Epoch 268/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0294 - val_loss: 0.0207
# Epoch 269/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.0207
# Epoch 270/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.0207
# Epoch 271/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0293 - val_loss: 0.0206
# Epoch 272/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.0206
# Epoch 273/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0292 - val_loss: 0.0206
# Epoch 274/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0292 - val_loss: 0.0206
# Epoch 275/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0292 - val_loss: 0.0206
# Epoch 276/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0292 - val_loss: 0.0206
# Epoch 277/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0291 - val_loss: 0.0206
# Epoch 278/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0291 - val_loss: 0.0206
# Epoch 279/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0291 - val_loss: 0.0206
# Epoch 280/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0291 - val_loss: 0.0206
# Epoch 281/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0290 - val_loss: 0.0206
# Epoch 282/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0290 - val_loss: 0.0205
# Epoch 283/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0290 - val_loss: 0.0205
# Epoch 284/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0290 - val_loss: 0.0205
# Epoch 285/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0289 - val_loss: 0.0205
# Epoch 286/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0289 - val_loss: 0.0205
# Epoch 287/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0289 - val_loss: 0.0205
# Epoch 288/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0289 - val_loss: 0.0205
# Epoch 289/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0288 - val_loss: 0.0205
# Epoch 290/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0288 - val_loss: 0.0205
# Epoch 291/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0288 - val_loss: 0.0205
# Epoch 292/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0288 - val_loss: 0.0204
# Epoch 293/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0287 - val_loss: 0.0204
# Epoch 294/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0287 - val_loss: 0.0204
# Epoch 295/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0287 - val_loss: 0.0204
# Epoch 296/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0287 - val_loss: 0.0204
# Epoch 297/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0287 - val_loss: 0.0204
# Epoch 298/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0286 - val_loss: 0.0204
# Epoch 299/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0286 - val_loss: 0.0204
# Epoch 300/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0286 - val_loss: 0.0204
# Epoch 301/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0286 - val_loss: 0.0204
# Epoch 302/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0286 - val_loss: 0.0204
# Epoch 303/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0285 - val_loss: 0.0203
# Epoch 304/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0285 - val_loss: 0.0203
# Epoch 305/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0285 - val_loss: 0.0203
# Epoch 306/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0285 - val_loss: 0.0203
# Epoch 307/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0284 - val_loss: 0.0203
# Epoch 308/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0284 - val_loss: 0.0203
# Epoch 309/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0284 - val_loss: 0.0203
# Epoch 310/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0284 - val_loss: 0.0203
# Epoch 311/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0284 - val_loss: 0.0203
# Epoch 312/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0283 - val_loss: 0.0203
# Epoch 313/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0283 - val_loss: 0.0203
# Epoch 314/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0283 - val_loss: 0.0202
# Epoch 315/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0283 - val_loss: 0.0202
# Epoch 316/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0283 - val_loss: 0.0202
# Epoch 317/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 318/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 319/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 320/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 321/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 322/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0202
# Epoch 323/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0281 - val_loss: 0.0202
# Epoch 324/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0202
# Epoch 325/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0202
# Epoch 326/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 327/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 328/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 329/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 330/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 331/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0202
# Epoch 332/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0202
# Epoch 333/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0201
# Epoch 334/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0279 - val_loss: 0.0201
# Epoch 335/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0279 - val_loss: 0.0201
# Epoch 336/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0278 - val_loss: 0.0201
# Epoch 337/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0278 - val_loss: 0.0201
# Epoch 338/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0278 - val_loss: 0.0201
# Epoch 339/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0278 - val_loss: 0.0201
# Epoch 340/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0278 - val_loss: 0.0201
# Epoch 341/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 342/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 343/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 344/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 345/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 346/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0277 - val_loss: 0.0201
# Epoch 347/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0276 - val_loss: 0.0201
# Epoch 348/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0276 - val_loss: 0.0201
# Epoch 349/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0276 - val_loss: 0.0201
# Epoch 350/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0276 - val_loss: 0.0201
# Epoch 351/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0276 - val_loss: 0.0201
# Epoch 352/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0201
# Epoch 353/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0201
# Epoch 354/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0201
# Epoch 355/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0201
# Epoch 356/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0200
# Epoch 357/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 358/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 359/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 360/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 361/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 362/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0274 - val_loss: 0.0200
# Epoch 363/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 364/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 365/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 366/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 367/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 368/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 369/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 370/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 371/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 372/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 373/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 374/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 375/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 376/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 377/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 378/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 379/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 0.0200
# Epoch 380/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0270 - val_loss: 0.0200
# Epoch 381/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0270 - val_loss: 0.0200
# Epoch 382/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0270 - val_loss: 0.0200
# Epoch 383/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0270 - val_loss: 0.0200
# Epoch 384/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0270 - val_loss: 0.0200
# Epoch 385/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0269 - val_loss: 0.0200
# Epoch 386/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0269 - val_loss: 0.0200
# Epoch 387/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0269 - val_loss: 0.0199
# Epoch 388/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0269 - val_loss: 0.0199
# Epoch 389/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0269 - val_loss: 0.0199
# Epoch 390/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0269 - val_loss: 0.0199
# Epoch 391/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 392/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 393/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 394/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 395/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 396/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0268 - val_loss: 0.0199
# Epoch 397/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 398/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 399/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 400/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 401/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 402/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0199
# Epoch 403/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 404/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 405/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 406/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 407/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 408/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 409/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 410/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 411/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 412/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 413/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 414/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 415/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0265 - val_loss: 0.0199
# Epoch 416/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 417/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 418/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 419/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 420/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 421/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0264 - val_loss: 0.0199
# Epoch 422/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 423/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 424/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 425/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 426/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 427/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0263 - val_loss: 0.0199
# Epoch 428/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 429/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 430/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 431/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 432/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 433/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0262 - val_loss: 0.0199
# Epoch 434/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 435/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 436/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 437/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 438/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 439/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 440/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 441/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 442/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 443/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 444/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 445/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0260 - val_loss: 0.0199
# Epoch 446/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 447/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 448/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 449/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 450/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 451/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0259 - val_loss: 0.0199
# Epoch 452/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 453/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 454/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 455/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 456/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 457/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 458/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 459/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 460/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 461/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 462/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 463/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 464/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0257 - val_loss: 0.0198
# Epoch 465/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 466/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 467/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 468/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 469/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 470/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0256 - val_loss: 0.0198
# Epoch 471/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 472/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 473/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 474/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 475/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 476/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0255 - val_loss: 0.0198
# Epoch 477/800
# ...
# Epoch 643/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0233 - val_loss: 0.0199
# Epoch 644/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0233 - val_loss: 0.0199
# Epoch 645/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0233 - val_loss: 0.0199
# Epoch 646/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 647/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 648/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 649/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 650/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 651/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 652/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 653/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 654/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0199
# Epoch 655/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.0199
# Epoch 656/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0231 - val_loss: 0.0199
# Epoch 657/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 658/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 659/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 660/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 661/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 662/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 663/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 664/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 665/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 666/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 667/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 668/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 669/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 670/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 671/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 672/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 673/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0230 - val_loss: 0.0200
# Epoch 674/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 675/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 676/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 677/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 678/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 679/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 680/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 681/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 682/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0229 - val_loss: 0.0200
# Epoch 683/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 684/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 685/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 686/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 687/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 688/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 689/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 690/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 691/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 692/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0200
# Epoch 693/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 694/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 695/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 696/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 697/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 698/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 699/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 700/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 701/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 702/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 703/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 704/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 705/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 706/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 707/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 708/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 709/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 710/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 711/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 712/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 713/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0226 - val_loss: 0.0201
# Epoch 714/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 715/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 716/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 717/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 718/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 719/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 720/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 721/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 722/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 723/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 724/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 725/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 726/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 727/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 728/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 729/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0224 - val_loss: 0.0201
# Epoch 730/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0202
# Epoch 731/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0202
# Epoch 732/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0224 - val_loss: 0.0202
# Epoch 733/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0202
# Epoch 734/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.0202
# Epoch 735/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 736/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 737/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 738/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 739/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 740/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 741/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 742/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 743/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 744/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 745/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 746/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 747/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 748/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 749/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 750/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 751/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 752/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 753/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 754/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 755/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 756/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 757/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 758/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 759/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 760/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 761/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 762/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 763/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 764/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 765/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 766/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 767/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 768/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0221 - val_loss: 0.0203
# Epoch 769/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 770/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 771/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 772/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 773/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 774/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 775/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 776/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 777/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 778/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 779/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 780/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 781/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0220 - val_loss: 0.0203
# Epoch 782/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 783/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 784/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 785/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 786/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 787/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 788/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 789/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 790/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 791/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 792/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 793/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0203
# Epoch 794/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 795/800
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 796/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 797/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 798/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 799/800
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0218 - val_loss: 0.0203
# Epoch 800/800
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0218 - val_loss: 0.0203

# %% [markdown]
# As we can observe, the loss is the training loss, and val_loss is the validation loss. Both are decereasing smoothly as the number of epochs is increasing, that means, our **model is learning in a natural way**.
#
# Next, **let's plot the validation and train error**, to check for any problems that a model can suffer from, such as underfitting or overfitting.

# %%
#Plot train and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.rcParams['figure.dpi'] = 360
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    
plot_loss (history_lstm, 'LSTM')

# %% [markdown]
# Before we start the testing phase, we need to inverse the normalization process that we applied to the data.

# %%
# inverse the y
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# %% [markdown]
# Define a function to inverse the X

# %%
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction

# %%
# Do predictions
prediction_LSTM = prediction(model_lstm)

# %%
## Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()

    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')

# %%
evaluate_prediction(prediction_LSTM, y_test, 'LSTM')
# Out:
# LSTM:
# Mean Absolute Error: 1535.3790
# Root Mean Square Error: 2083.2368
